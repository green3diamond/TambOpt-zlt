# %%
import numpy as np
from pina import Trainer, Condition, LabelTensor
from pina.solver import GAROM
from pina.callback import MetricTracker
from pina.model import FeedForward
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from pina.problem.zoo import SupervisedProblem
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 from pina import Trainer, Condition, LabelTensor
#       3 from pina.solver import GAROM
#       4 from pina.callback import MetricTracker
#
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/pina/__init__.py:13
#       1 """Module for the Pina library."""
#       3 __all__ = [
#       4     "Trainer",
#       5     "LabelTensor",
#    (...)
#      10     "MultiSolverInterface",
#      11 ]
# ---> 13 from .label_tensor import LabelTensor
#      14 from .graph import Graph
#      15 from .solver import SolverInterface, MultiSolverInterface
#
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/pina/label_tensor.py:4
#       1 """Module for LabelTensor"""
#       3 from copy import copy, deepcopy
# ----> 4 import torch
#       5 from torch import Tensor
#       8 class LabelTensor(torch.Tensor):
#
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/torch/__init__.py:367
#     365     if USE_GLOBAL_DEPS:
#     366         _load_global_deps()
# --> 367     from torch._C import *  # noqa: F403
#     370 class SymInt:
#     371     """
#     372     Like an int (including magic methods), but redirects all operations on the
#     373     wrapped node. This is used in particular to symbolically record operations
#     374     in the symbolic shape workflow.
#     375     """
#
# File <frozen importlib._bootstrap>:463, in _lock_unlock_module(name)
#
# KeyboardInterrupt:

# %%
class Generator(nn.Module):

    def __init__(
        self,
        input_dimension=1,
        parameters_dimension=1,
        noise_dimension=1,
        activation=torch.nn.SiLU,
    ):
        super().__init__()

        self._noise_dimension = noise_dimension
        self._activation = activation
        self.model = FeedForward(6 * noise_dimension, input_dimension)
        self.condition = FeedForward(parameters_dimension, 5 * noise_dimension)
        self.parameters_dimension = parameters_dimension

    def forward(self, param):
        # uniform sampling in [-1, 1]
        z = (
            2
            * torch.rand(
                size=(param.shape[0], self._noise_dimension),
                device=param.device,
                dtype=param.dtype,
                requires_grad=True,
            )
            - 1
        )
        return self.model(torch.cat((z, self.condition(param.reshape(-1, self.parameters_dimension))), dim=-1))

# %%
class Discriminator(nn.Module):

    def __init__(
        self,
        input_dimension=1,
        parameter_dimension=1,
        hidden_dimension=2,
        activation=torch.nn.ReLU,
    ):
        super().__init__()

        self._activation = activation
        self.encoding = FeedForward(input_dimension, hidden_dimension)
        self.decoding = FeedForward(2 * hidden_dimension, 1)
        self.condition = FeedForward(parameter_dimension, hidden_dimension)
        self.parameter_dimension = parameter_dimension

    def forward(self, data):
        x, condition = data
        encoding = self.encoding(x)
        conditioning = torch.cat((encoding, self.condition(condition.reshape(-1,self.parameter_dimension))), dim=-1)
        decoding = self.decoding(conditioning)
        return decoding

# %%
# Generate 10 noisy sine wave data of dimension 100
DIM = 100
SAMPLES = 20

x = np.linspace(0, 2 * np.pi, DIM)
param = np.linspace(0, 20, SAMPLES)

# Generate y for each frequency with noise
# x_array = []
y_array = []
for freq in param:
    noise = 0.1 * np.random.normal(size=x.shape)
    y = np.sin(freq * x) + noise
    y_array.append(y)
    # x_array.append(x)

# x_array = np.array(x_array)
y_array = np.array(y_array)  # Shape: (len(param), dim)


# predict clean signal given noise signal (denoise)
problem = SupervisedProblem(
    torch.tensor(param, dtype=torch.float32),
    torch.tensor(y_array, dtype=torch.float32),
)


generator = Generator(input_dimension=DIM, parameters_dimension=1)
discriminator = Discriminator(input_dimension=DIM, parameter_dimension=1)

solver = GAROM(problem, generator, discriminator)

# %%
trainer = Trainer(
    solver=solver,
    max_epochs=4500,
    logger=True,
    callbacks=[MetricTracker()],
    accelerator="cpu",
    train_size=0.7,
    test_size=0.2,
    val_size=0.1,
    enable_model_summary=False,

)

trainer.train()
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00, 59.78it/s, v_num=96]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 175.00it/s]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00, 77.01it/s, v_num=96, val_loss=0.659, d_loss=0.601, g_loss=0.169, stability_metric=0.607, data_loss=0.610, train_loss=0.610]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 173.82it/s]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 90.58it/s, v_num=96, val_loss=0.654, d_loss=0.600, g_loss=0.160, stability_metric=0.615, data_loss=0.609, train_loss=0.609]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 186.41it/s]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00, 96.67it/s, v_num=96, val_loss=0.649, d_loss=0.599, g_loss=0.153, stability_metric=0.616, data_loss=0.608, train_loss=0.608]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 194.88it/s]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00, 91.91it/s, v_num=96, val_loss=0.658, d_loss=0.598, g_loss=0.146, stability_metric=0.624, data_loss=0.608, train_loss=0.608]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 197.64it/s]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 75.20it/s, v_num=96, val_loss=0.650, d_loss=0.597, g_loss=0.143, stability_metric=0.632, data_loss=0.609, train_loss=0.609]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 164.50it/s]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 93.60it/s, v_num=96, val_loss=0.655, d_loss=0.597, g_loss=0.131, stability_metric=0.633, data_loss=0.608, train_loss=0.608]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 225.57it/s]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 82.93it/s, v_num=96, val_loss=0.655, d_loss=0.595, g_loss=0.119, stability_metric=0.645, data_loss=0.608, train_loss=0.608]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 92.96it/s]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 61.36it/s, v_num=96, val_loss=0.654, d_loss=0.594, g_loss=0.105, stability_metric=0.661, data_loss=0.606, train_loss=0.606]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 193.77it/s]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 77.15it/s, v_num=96, val_loss=0.652, d_loss=0.593, g_loss=0.106, stability_metric=0.664, data_loss=0.606, train_loss=0.606]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 179.17it/s]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 88.08it/s, v_num=96, val_loss=0.652, d_loss=0.594, g_loss=0.100, stability_metric=0.666, data_loss=0.605, train_loss=0.605]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 156.32it/s]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 81.65it/s, v_num=96, val_loss=0.648, d_loss=0.594, g_loss=0.0988, stability_metric=0.673, data_loss=0.604, train_loss=0.604]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 165.83it/s]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 85.85it/s, v_num=96, val_loss=0.650, d_loss=0.594, g_loss=0.0986, stability_metric=0.672, data_loss=0.605, train_loss=0.605]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,

# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 190.73it/s]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 67.60it/s, v_num=96, val_loss=0.643, d_loss=0.593, g_loss=0.0693, stability_metric=0.700, data_loss=0.601, train_loss=0.601]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 218.21it/s]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00, 98.36it/s, v_num=96, val_loss=0.637, d_loss=0.593, g_loss=0.0662, stability_metric=0.702, data_loss=0.600, train_loss=0.600]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 189.38it/s]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 96.76it/s, v_num=96, val_loss=0.640, d_loss=0.593, g_loss=0.0605, stability_metric=0.708, data_loss=0.600, train_loss=0.600]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 227.16it/s]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00, 100.51it/s, v_num=96, val_loss=0.637, d_loss=0.593, g_loss=0.0587, stability_metric=0.712, data_loss=0.600, train_loss=0.600]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 207.28it/s]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00, 83.70it/s, v_num=96, val_loss=0.637, d_loss=0.593, g_loss=0.055, stability_metric=0.715, data_loss=0.601, train_loss=0.601]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 188.30it/s]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00, 104.85it/s, v_num=96, val_loss=0.640, d_loss=0.593, g_loss=0.052, stability_metric=0.719, data_loss=0.600, train_loss=0.600]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 172.09it/s]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 89.04it/s, v_num=96, val_loss=0.639, d_loss=0.593, g_loss=0.0495, stability_metric=0.724, data_loss=0.599, train_loss=0.599]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 205.62it/s]
# Epoch 35: 100%|██████████| 1/1 [00:00<00:00, 99.43it/s, v_num=96, val_loss=0.637, d_loss=0.593, g_loss=0.0465, stability_metric=0.725, data_loss=0.600, train_loss=0.600]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 203.34it/s]
# Epoch 35: 100%|██████████| 1/1 [00:00<00:00, 38.85it/s, v_num=96, val_loss=0.636, d_loss=0.593, g_loss=0.0444, stability_metric=0.726, data_loss=0.599, train_loss=0.599]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /home/zgdi/anaconda3/envs/ml/lib/python3.12/site-packages/IPython/core/interactiveshell.py: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.

# %%
# plot loss
trainer_metrics = trainer.callbacks[0].metrics
loss = trainer_metrics["train_loss"]
epochs = range(len(loss))

plt.plot(epochs, loss.cpu())
# plotting
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")

all_outputs = []
all_targets = []
all_inputs = []
trainer.data_module.setup("test")
with torch.no_grad():
    for data in trainer.data_module.test_dataloader():
        # for data in trainer.data_module.train_dataloader():
        inputs, target = data[0][1]["input"], data[0][1]["target"]
        outputs = solver(inputs)
        all_inputs.append(inputs)
        all_outputs.append(outputs)
        all_targets.append(target)
        break

# %%
# plot targets vs predictions for validation set
y_mean = torch.stack(all_outputs, dim=0).detach()
true_output = torch.stack(all_targets, dim=0).detach()


# use 3 columns per row
i=0
plt.scatter(true_output[:, i], y_mean[:, i], alpha=0.5)
plt.plot(
    [true_output[:, i].min(), true_output[:, i].max()],
    [true_output[:, i].min(), true_output[:, i].max()],
    "r--",
)
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.show()
