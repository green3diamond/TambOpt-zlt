# %%
#Import all the necessary libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm
from matplotlib.colors import Normalize
from torch.utils.data import TensorDataset, DataLoader
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Import all the necessary libraries
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import torch.nn.functional as F
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/__init__.py:2161
#    2154 from torch._compile import _disable_dynamo  # usort: skip
#    2156 ################################################################################
#    2157 # Import interface functions defined in Python
#    2158 ################################################################################
#    2159
#    2160 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 2161 from torch import _VF as _VF, functional as functional  # usort: skip
#    2162 from torch.functional import *  # usort: skip # noqa: F403
#    2164 ################################################################################
#    2165 # Remove unnecessary members
#    2166 ################################################################################
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/functional.py:8
#       5 from typing import Any, Optional, TYPE_CHECKING, Union
#       7 import torch
# ----> 8 import torch.nn.functional as F
#       9 from torch import _VF, Tensor
#      10 from torch._C import _add_docstr
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/nn/__init__.py:8
#       1 # mypy: allow-untyped-defs
#       2 from torch.nn.parameter import (  # usort: skip
#       3     Buffer as Buffer,
#       4     Parameter as Parameter,
#       5     UninitializedBuffer as UninitializedBuffer,
#       6     UninitializedParameter as UninitializedParameter,
#       7 )
# ----> 8 from torch.nn.modules import *  # usort: skip # noqa: F403
#       9 from torch.nn import (
#      10     attention as attention,
#      11     functional as functional,
#    (...)     16     utils as utils,
#      17 )
#      18 from torch.nn.parallel import DataParallel as DataParallel
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/nn/modules/__init__.py:2
#       1 from .module import Module  # usort: skip
# ----> 2 from .linear import Bilinear, Identity, LazyLinear, Linear  # usort: skip
#       3 from .activation import (
#       4     CELU,
#       5     ELU,
#    (...)     32     Threshold,
#      33 )
#      34 from .adaptive import AdaptiveLogSoftmaxWithLoss
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/nn/modules/linear.py:7
#       5 import torch
#       6 from torch import Tensor
# ----> 7 from torch.nn import functional as F, init
#       8 from torch.nn.parameter import Parameter, UninitializedParameter
#      10 from .lazy import LazyModuleMixin
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/nn/functional.py:11
#       9 from torch import _VF, sym_int as _sym_int, Tensor
#      10 from torch._C import _add_docstr, _infer_size
# ---> 11 from torch._jit_internal import (
#      12     _overload,
#      13     boolean_dispatch,
#      14     BroadcastingList1,
#      15     BroadcastingList2,
#      16     BroadcastingList3,
#      17 )
#      18 from torch._torch_docs import reproducibility_notes, sparse_support_notes, tf32_notes
#      19 from torch.nn import _reduction as _Reduction, grad  # noqa: F401
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/_jit_internal.py:44
#      39 import torch
#      41 # This is needed. `torch._jit_internal` is imported before `torch.distributed.__init__`.
#      42 # Explicitly ask to import `torch.distributed.__init__` first.
#      43 # Otherwise, "AttributeError: module 'torch' has no attribute 'distributed'" is raised.
# ---> 44 import torch.distributed.rpc
#      45 import torch.package._mangling as package_mangling
#      46 from torch._awaits import _Await
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/distributed/rpc/__init__.py:85
#      83 from .backend_registry import BackendType
#      84 from .options import TensorPipeRpcBackendOptions  # noqa: F401
# ---> 85 from .server_process_global_profiler import _server_process_global_profile
#      87 rendezvous_iterator: Generator[tuple[Store, int, int], None, None]
#      89 __all__ += ["init_rpc", "BackendType", "TensorPipeRpcBackendOptions"]
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/distributed/rpc/server_process_global_profiler.py:7
#       4 import itertools
#       6 import torch
# ----> 7 from torch.autograd.profiler_legacy import profile
#       9 from . import (
#      10     _disable_server_process_global_profiler,
#      11     _enable_server_process_global_profiler,
#      12 )
#      15 __all__: list[str] = []
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/autograd/__init__.py:589
#     562 from torch._C._autograd import (
#     563     _add_metadata_json,
#     564     _disable_profiler,
#    (...)    585     SavedTensor,
#     586 )
#     587 from torch._C._profiler import ProfilerActivity, ProfilerConfig, ProfilerState
# --> 589 from . import profiler
#     592 def _register_py_tensor_class_for_device(device, cls):
#     593     if not isinstance(cls, type):
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/autograd/profiler.py:28
#      13 from torch._C._profiler import _ExperimentalConfig
#      14 from torch.autograd import (
#      15     _disable_profiler,
#      16     _enable_profiler,
#    (...)     26     ProfilerState,
#      27 )
# ---> 28 from torch.autograd.profiler_util import (
#      29     _filter_name,
#      30     _filter_stack_entry,
#      31     _rewrite_name,
#      32     EventList,
#      33     FunctionEvent,
#      34     MEMORY_EVENT_NAME,
#      35     MemRecordsAcc,
#      36     OUT_OF_MEMORY_EVENT_NAME,
#      37 )
#      38 from torch.futures import Future
#      41 __all__ = [
#      42     "profile",
#      43     "record_function",
#    (...)     52     "MemRecordsAcc",
#      53 ]
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1322, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1262, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1559, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1533, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1665, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:166, in _path_isfile(path)
#
# File <frozen importlib._bootstrap_external>:158, in _path_is_mode_type(path, mode)
#
# File <frozen importlib._bootstrap_external>:152, in _path_stat(path)
#
# KeyboardInterrupt:

# %% [markdown]
# # Functions

# %% [markdown]
# ### Ready Functions

# %%
#This function evaluates the specific angular coefficients at given energy value

def Y(energy, f_mode):
    """Evaluate angular coefficient vector Y for given energy and mode.

    Parameters:
        energy (torch.Tensor): input energy (expected in PeV-range; scalar or 1-element tensor).
        f_mode (str): mode string selecting parameterization (e.g. 'mg0','mg2','eg0',...).

    Returns:
        torch.Tensor: shape (4, 1) tensor with evaluated coefficients used by interpolation routines.
    """
    Y = torch.zeros((4, 1))

    #Convert Energy to PeV
    xe = .5 + 20 * (torch.log(energy) - log_01) / (log_10 - log_01)
    xe2 = xe * xe

    #Evaluate Y for given energy and mode
    for i in range(4):
        if f_mode == "mg0":
            Y[i] = torch.exp(PXmg_p[i, 0, 0]) + torch.exp(PXmg_p[i ,0, 1] * torch.pow(xe, PXmg_p[i, 0, 2]))

        elif f_mode == "mg2":
            Y[i] = PXmg_p[i, 2, 0] + PXmg_p[i, 2, 1] * xe + PXmg_p[i, 2, 2] * xe2

        elif f_mode == "eg0":
            Y[i] = PXeg_p[i, 0, 0] * torch.exp(PXeg_p[i, 0, 1] * torch.pow(xe, PXeg_p[i, 0, 2]))

        elif f_mode == "eg1":
            Y[i] = PXeg_p[i, 1, 0] + PXeg_p[i, 1, 1] * xe + PXeg_p[i, 1, 2] * xe2

        elif f_mode == "eg2":
            Y[i] = PXeg_p[i, 2, 0] + PXeg_p[i, 2, 1] * xe + PXeg_p[i, 2, 2] * xe2

        elif f_mode == "mp0":
            Y[i] = torch.exp(PXmp_p[i, 0, 0]) + torch.exp(PXmp_p[i, 0, 1] * torch.pow(xe, PXmp_p[i, 0, 2]))

        elif f_mode == "mp2":
            Y[i] = PXmp_p[i, 2, 0] + PXmp_p[i, 2, 1] * xe + PXmp_p[i, 2, 2] * xe2

        elif f_mode == "ep0":
            Y[i] = torch.exp(PXep_p[i, 0, 0]) + torch.exp(PXep_p[i, 0, 1] * torch.pow(xe, PXep_p[i, 0, 2]))

        elif f_mode == "ep1":
            Y[i] = PXep_p[i, 1, 0] + PXep_p[i, 1, 1] * xe + PXep_p[i, 1, 2] * xe2

        elif f_mode == "ep2":
            Y[i] = PXep_p[i, 2, 0] + PXep_p[i, 2, 1] * xe + PXep_p[i, 2, 2] * xe2

        else:
            warnings.warn("The Mode is not defined")
            return

    return Y

# %%
#Interpolated parameter computation
#thisp0 = normalization constant
#thisp1 = slope parameter
#thisp2 = shape parameter

def thisp(energy, theta, f_mode):
    """Compute interpolated parameter value for a given energy, incident angle and parameter mode.

    The function evaluates the angular coefficients via `Y`, solves a small linear system to get
    polynomial coefficients `B`, then evaluates a polynomial in `x(theta)` to return a single parameter.

    Parameters:
        energy (torch.Tensor): shower energy.
        theta (torch.Tensor): shower incident angle.
        f_mode (str): mode string (e.g. 'mg0', 'eg1', 'mp2').

    Returns:
        torch.Tensor: interpolated scalar parameter value used in the flux parametrization.
    """
    #Find Y values
    Y_val = Y(energy, f_mode)

    #Solve for B
    B = torch.linalg.solve(A, Y_val)

    #Define x from theta
    x = .5 + 4 * theta / theta_max

    res = 0

    for i in range(4):
        res += B[i] * x ** i

    return res

# %%
def ReadShowers(path_g, path_p):
    """Read fitted parameter blocks for gamma and proton showers from text files.

    Expects both files to contain 4 parameter blocks for electrons and muons (each block of 3 rows
    and 3 columns). Performs a simple validation (warns and returns None if a block contains zeros)
    and returns the parameter tensors as torch.Tensor objects.

    Parameters:
        path_g (str): path to gamma-fit text file.
        path_p (str): path to proton-fit text file.

    Returns:
        tuple: (PXmg_p, PXeg_p, PXmp_p, PXep_p) each a torch.Tensor of shape (4,3,3), or None on error.
    """
    #GAMMA SHOWERS
    #Reading the Electron Parameters in the Showers
    PXeg1_p = np.loadtxt(path_g, max_rows = 3)

    for i in range(3):
        if PXeg1_p[i, 0]*PXeg1_p[i, 1]*PXeg1_p[i, 2] == 0:
            warnings.warn("Encountered 0")
            return

    PXeg2_p = np.loadtxt(path_g, skiprows = 3, max_rows = 3)
    
    for i in range(3):
        if PXeg2_p[i, 0]*PXeg2_p[i, 1]*PXeg2_p[i, 2] == 0:
            warnings.warn("Encountered 0")
            return

    PXeg3_p = np.loadtxt(path_g, skiprows = 6, max_rows = 3)
    
    for i in range(3):
        if PXeg3_p[i, 0]*PXeg3_p[i, 1]*PXeg3_p[i, 2] == 0:
            warnings.warn("Encountered 0")
            return

    PXeg4_p = np.loadtxt(path_g, skiprows = 9, max_rows = 3)
    
    for i in range(3):
        if PXeg4_p[i, 0]*PXeg4_p[i, 1]*PXeg4_p[i, 2] == 0:
            warnings.warn("Encountered 0")
            return
            
    #Reading the Muon Parameters in the Showers
    PXmg1_p = np.loadtxt(path_g, skiprows = 12, max_rows = 3)
    
    for i in range(3):
        if PXmg1_p[i, 0]*PXmg1_p[i, 1]*PXmg1_p[i, 2] == 0 and i != 1:
            warnings.warn("Encountered 0")
            return
            
    PXmg2_p = np.loadtxt(path_g, skiprows = 15, max_rows = 3)
    
    for i in range(3):
        if PXmg2_p[i, 0]*PXmg2_p[i, 1]*PXmg2_p[i, 2] == 0 and i != 1:
            warnings.warn("Encountered 0")
            return

    PXmg3_p = np.loadtxt(path_g, skiprows = 18, max_rows = 3)
    
    for i in range(3):
        if PXmg3_p[i, 0]*PXmg3_p[i, 1]*PXmg3_p[i, 2] == 0 and i != 1:
            warnings.warn("Encountered 0")
            return

    PXmg4_p = np.loadtxt(path_g, skiprows = 21, max_rows = 3)
    
    for i in range(3):
        if PXmg4_p[i, 0]*PXmg4_p[i, 1]*PXmg4_p[i, 2] == 0 and i != 1:
            warnings.warn("Encountered 0")
            return

    #PROTON SHOWERS
    #Reading the Electron Parameters in the Showers
    PXep1_p = np.loadtxt(path_p, max_rows = 3)

    for i in range(3):
        if PXep1_p[i, 0]*PXep1_p[i, 1]*PXep1_p[i, 2] == 0:
            warnings.warn("Encountered 0")
            return

    PXep2_p = np.loadtxt(path_p, skiprows = 3, max_rows = 3)
    
    for i in range(3):
        if PXep2_p[i, 0]*PXep2_p[i, 1]*PXep2_p[i, 2] == 0:
            warnings.warn("Encountered 0")
            return

    PXep3_p = np.loadtxt(path_p, skiprows = 6, max_rows = 3)
    
    for i in range(3):
        if PXep3_p[i, 0]*PXep3_p[i, 1]*PXep3_p[i, 2] == 0:
            warnings.warn("Encountered 0")
            return

    PXep4_p = np.loadtxt(path_p, skiprows = 9, max_rows = 3)
    
    for i in range(3):
        if PXep4_p[i, 0]*PXep4_p[i, 1]*PXep4_p[i, 2] == 0:
            warnings.warn("Encountered 0")
            return
            
    #Reading the Muon Parameters in the Showers
    PXmp1_p = np.loadtxt(path_p, skiprows = 12, max_rows = 3)
    
    for i in range(3):
        if PXmp1_p[i, 0]*PXmp1_p[i, 1]*PXmp1_p[i, 2] == 0 and i != 1:
            warnings.warn("Encountered 0")
            return

    PXmp2_p = np.loadtxt(path_p, skiprows = 15, max_rows = 3)
    
    for i in range(3):
        if PXmp2_p[i, 0]*PXmp2_p[i, 1]*PXmp2_p[i, 2] == 0 and i != 1:
            warnings.warn("Encountered 0")
            return

    PXmp3_p = np.loadtxt(path_p, skiprows = 18, max_rows = 3)
    
    for i in range(3):
        if PXmp3_p[i, 0]*PXmp3_p[i, 1]*PXmp3_p[i, 2] == 0 and i != 1:
            warnings.warn("Encountered 0")
            return

    PXmp4_p = np.loadtxt(path_p, skiprows = 21, max_rows = 3)
    
    for i in range(3):
        if PXmp4_p[i, 0]*PXmp4_p[i, 1]*PXmp4_p[i, 2] == 0 and i != 1:
            warnings.warn("Encountered 0")
            return

    PXmg_p = torch.tensor([PXmg1_p, PXmg2_p, PXmg3_p, PXmg4_p])
    PXeg_p = torch.tensor([PXeg1_p, PXeg2_p, PXeg3_p, PXeg4_p])
    PXmp_p = torch.tensor([PXmp1_p, PXmp2_p, PXmp3_p, PXmp4_p])
    PXep_p = torch.tensor([PXep1_p, PXep2_p, PXep3_p, PXep4_p])

    return PXmg_p, PXeg_p, PXmp_p, PXep_p

# %%
#This function defines the initial layouts of the detectors, N_det = 90
#At this point of the project, we just define a square grid

def Layouts():
    """Create an initial detector layout (concentric rings) and return x and y coordinates.

    Returns:
        tuple: two lists (x, y) with detector positions in meters.
    """
    R = [50, 200, 350, 550, 750, 1000]
    x = []
    y = []

    for i, r in enumerate(R):
        if i == 0:
            for j in range(3):
                x.append(r * np.cos(j *np.pi * 2 / 3))
                y.append(r * np.sin(j *np.pi * 2 / 3))

        if i == 1:
            for j in range(9):
                x.append(r * np.cos(j * np.pi * 2 / 9))
                y.append(r * np.sin(j * np.pi * 2 / 9))

        if i == 2:
            for j in range(12):
                x.append(r * np.cos(j * np.pi * 2 / 12))
                y.append(r * np.sin(j * np.pi * 2 / 12))

        if i == 3:
            for j in range(15):
                x.append(r * np.cos(j * np.pi * 2 / 15))
                y.append(r * np.sin(j * np.pi * 2 / 15))

        if i == 4:
            for j in range(18):
                x.append(r * np.cos(j * np.pi * 2 / 18))
                y.append(r * np.sin(j * np.pi * 2 / 18))

        if i == 5:
            for j in range(33):
                x.append(r * np.cos(j * np.pi * 2 / 33))
                y.append(r * np.sin(j * np.pi * 2 / 33))
            
    return x, y

# %% [markdown]
# ### Functions to redo

# %% [markdown]
# #### Instantiate generator

# %%
from diffusion_model.tambo_diffusion_generator import TamboDiffusionGenerator

# Initialize with custom parameters
generator = TamboDiffusionGenerator(
        checkpoint_path="/n/holylfs05/LABS/arguelles_delgado_lab/Everyone/hhanif/tambo_ckpts/diffusion/ckpt_epoch=1999.ckpt",
        output_dir="diffusion_model/run_3",
        tambo_optimization_path="/n/holylfs05/LABS/arguelles_delgado_lab/Everyone/hhanif/tambo_optimization",
        device="cuda:0",
        ddim_steps=3
    )

generator.load_model()
# Out:
# ✅ Built 46942 rows across 200 files (one row per file/id).
# Initialized TamboDiffusionGenerator
# Device: cuda:0
# Output directory: diffusion_model/run_3
# Loaded checkpoint: /n/holylfs05/LABS/arguelles_delgado_lab/Everyone/hhanif/tambo_ckpts/diffusion/ckpt_epoch=1999.ckpt
# Model set to eval mode.
# DDIM sampler built (ddim_steps=100, eta=0.0)
# Model loading time: 1.40s

# %%
def GenerateShowers(x, y):
    """Randomly generate the showers, getting the energy, angle, and position of the shower core

    Parameters:
        x (torch.Tensor): detector x positions.
        y (torch.Tensor): detector y positions.

    Returns:
        tuple: (N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a)
            N (torch.Tensor): per-detector counts (Ne + Nm).
            T (torch.Tensor): per-detector time-of-arrival.
            X0, Y0 (torch.Tensor): shower core position.
            energy, sin_z, cos_z, sin_a, cos_a (torch.Tensor): shower truth parameters.
    """

    #Define the energy and angles
    energy = torch.tensor([np.random.uniform(.1, 10)], dtype = torch.float32)
    theta = torch.tensor([np.random.uniform(0, theta_max)], dtype = torch.float32)
    phi = torch.tensor([np.random.uniform(-np.pi, np.pi)], dtype = torch.float32)
    # split theta and phi in cos and sin components if needed
    sin_z = torch.sin(theta)
    cos_z = torch.cos(theta)
    sin_a = torch.sin(phi)
    cos_a = torch.cos(phi)

    # input parameters 
    generator.test_conditions = torch.tensor([[energy, sin_z, cos_z, sin_a, cos_a]])
    # generate shower
    outputs_arr = generator.generate_samples(num_samples=1, num_conditions=1, chunk_size=1)
    shower_rgb = outputs_arr[0]['images']
    shower_rgb = shower_rgb[0].permute(1,2,0)
    
    # compute x0, y0 after generating the shower from the mean of the distribution over x, y
    location_means = torch.mean(shower_rgb, dim=2)
    # Create position grids
    i_indices = torch.arange(32, dtype=torch.float32)
    j_indices = torch.arange(32, dtype=torch.float32)
    i_grid, j_grid = torch.meshgrid(i_indices, j_indices, indexing='ij')

    # Calculate position-weighted mean coefficients
    X0 = torch.sum(i_grid * location_means) / torch.sum(location_means)
    Y0 = torch.sum(j_grid * location_means) / torch.sum(location_means)
    
    #Evalute the counts in the tanks
    N, T = GetCounts(shower_rgb, x, y, X0, Y0)

    return N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a

# %%
def GetCounts(shower_rgb, x, y, X0, Y0):
    """Compute per-detector particle counts and times from a shower RGB map.
    
    Parameters:
        shower_rgb: (32, 32, 3) tensor - spatial shower distribution on the ground.
        x, y: detector positions (tensor or iterable).
        X0, Y0: shower core position.
    
    Returns:
        tuple: (Ne + Nm, Te) - total counts per detector and arrival times.
    """
    grid_size = 2000
    muon_scale_factor = 10.0  # scale factor to convert intensity to muon counts
    electron_scale_factor = 20.0  # scale factor to convert intensity to electron counts
    c_light = 0.3  # speed of light in m/ns
    
    # Extract particle density/intensity from the third channel or overall intensity
    particle_density = shower_rgb.mean(dim=2)
    
    Nm_list, Ne_list, Tm_list, Te_list = [], [], [], []

    for idx in range(len(x)):
        # Find nearest pixel in the shower map
        x_idx = int(torch.clamp((x[idx] - X0 + grid_size/2) / grid_size * 32, 0, 31))
        y_idx = int(torch.clamp((y[idx] - Y0 + grid_size/2) / grid_size * 32, 0, 31))
        
        # Sample particle count from the RGB map at detector location
        local_intensity = particle_density[y_idx, x_idx]
        
        # Convert intensity to particle counts
        m0 = local_intensity * muon_scale_factor  # adjust scale factors as needed
        e0 = local_intensity * electron_scale_factor
        
        # Smear and add background
        nms = SmearN(m0)
        nes = SmearN(e0)
        nmb = SmearN(fluxB_m)
        neb = SmearN(fluxB_e)

        Nm_i = nms + nmb
        Ne_i = nes + neb

        Nm_list.append(Nm_i)
        Ne_list.append(Ne_i)

        # Compute arrival time based on distance from core
        dx = x[idx] - X0
        dy = y[idx] - Y0
        R = torch.sqrt(dx**2 + dy**2)
        et = R / c_light  # time of arrival (adjust with shower front geometry if needed)

        if Ne_i > 0:
            TAe_m, TAe_s = TimeAverage(et, neb, nes)
            Te_val = TAe_m + torch.randn_like(TAe_m) * TAe_s
            Te_list.append(Te_val.reshape(()))
        else:
            Te_list.append(torch.tensor(0.0))

        if Nm_i > 0:
            TAm_m, TAm_s = TimeAverage(et, nmb, nms)
            Tm_val = TAm_m + torch.randn_like(TAm_m) * TAm_s
            Tm_list.append(Tm_val.reshape(()))
        else:
            Tm_list.append(torch.tensor(0.0))

    Nm = torch.stack(Nm_list)
    Ne = torch.stack(Ne_list)
    Te = torch.stack(Te_list)

    return Ne + Nm, Te

# %%
def ShowerContent(energy, theta, R, f_mode):
    """Parametrize particle flux (content) at a detector for a shower.

    This function parametrize the particle species content from the showers
    We find the flux of the particles for a given energy, angle and distance
    f_mode is used to tell the code which particle species we are dealing with, beacuse equation changes
    whether we are dealing with muons or electrons

    Parameters:
        energy (torch.Tensor): shower energy.
        theta (torch.Tensor): incident angle.
        R (torch.Tensor): effective distance from shower core to detector (m).
        f_mode (str): particle mode: 'mg','mp' for muons; 'eg','ep' for electrons.

    Returns:
        torch.Tensor: clamped flux value (number of particles expected in detector area).
    """
    pass

# %% [markdown]
# ### Rest of the functions

# %%
#This function evaluates the distance of the given unit from the shower core
def EffectiveDistance(xd, yd, x0, y0, th, ph):
    """Compute effective lateral distance from shower axis to detector.

    Uses geometry to project the detector position onto plane perpendicular to shower direction.

    Parameters:
        xd, yd: detector coordinates.
        x0, y0: shower core coordinates.
        th, ph: shower arrival angles.

    Returns:
        torch.Tensor: effective distance (clamped to R_min).
    """
    dx = xd - x0
    dy = yd - y0
    t = torch.sin(th) * torch.cos(ph) * dx + torch.sin(th) * torch.sin(ph) * dy
    r = dx ** 2 + dy ** 2 - t ** 2

    r = torch.where(r > 0, torch.sqrt(r), torch.zeros_like(r))  # or any fallback like r=r
    r = torch.clamp(r, min = R_min)

    return r

# %%
#This function evaluates the time of arrival of the particles to the ground
#t = 0 for first arrivals while t > 0 for late arrival particles

def EffectiveTime(xd, yd, x0, y0, th, ph):
    """Compute expected time-of-arrival at a detector relative to a reference, based on shower geometry.

    Parameters:
        xd, yd: detector coordinates.
        x0, y0: shower core coordinates.
        th, ph: shower arrival angles.

    Returns:
        torch.Tensor: expected arrival time in ns.
    """
    et = ((xd - x0) * torch.sin(th) * torch.cos(ph) + (yd - y0) * torch.sin(th) * torch.sin(ph)) / c0

    return et

# %%
#We have some resolution in our detectors, which inherently has some uncertainty in detecting the number of particles
#This function accounts for this uncertainty
#We keep a fix resolution, it does not change for different flux values

def SmearN(flux):
    """Apply detector resolution and threshold gating to expected flux values.

    Parameters:
        flux (torch.Tensor): expected number of particles.

    Returns:
        torch.Tensor: noisy, gated counts reflecting detector response.
    """
    gate = torch.sigmoid(10 * (flux - 0.1))
    noise = torch.randn_like(flux)  # standard normal noise
    noisy = flux + RelResCounts * flux * noise  # reparameterized: mean + std * noise
    
    return gate * noisy

# %%
def TimeAverage(T, Nb, Ns):
    """Estimate time mean and uncertainty combining background and signal statistics.

    Parameters:
        T (torch.Tensor): expected arrival time.
        Nb (float): background counts.
        Ns (float): signal counts.

    Returns:
        tuple: (mean, std) representing the time mean and its standard deviation used for sampling.
    """
    noise = torch.rand_like(T) - .5
    
    if Nb <= 1:
        STbgr = IntegrationWindow / sqrt12
        AvTbgr = T + noise * STbgr

    elif Nb <= 2:
        STbgr = IntegrationWindow * .2041
        AvTbgr = T + noise * STbgr

    elif Nb <= 3:
        STbgr = IntegrationWindow * .166666
        AvTbgr = T + noise * STbgr

    elif Nb <= 4:
        STbgr = IntegrationWindow * .1445
        AvTbgr = T + noise * STbgr

    else:
        STbgr = IntegrationWindow * .11
        AvTbgr = torch.normal(T, STbgr)
        
        while (AvTbgr - T > .5 * IntegrationWindow):
            AvTbgr = torch.normal(T, STbgr)

    STsig = sigma_time

    if Ns >= 2:
        STsig = sigma_time / torch.sqrt(Ns - 1)

    AvTsig = T + torch.randn_like(T) * STbgr

    if Nb == 0 and Ns == 0:
        mean = T
        std = IntegrationWindow / sqrt12

    elif Nb == 0:
        mean = AvTsig
        std = STsig

    elif Ns == 0:
        mean = AvTbgr
        std = STbgr

    else:
        VTbgr = STbgr ** 2
        VTsig = STsig ** 2
        var = torch.sqrt(1 / VTbgr + 1 / VTsig)

        mean = (AvTsig / VTsig + AvTbgr / VTsig) / var
        std = torch.sqrt(var)

    return mean, std

# %%
def powerlawdist(E_min = 0.1, E_max = 10, index = 2.7):
    """Sample an energy from a power-law distribution using inverse transform sampling.

    Parameters:
        E_min (float): minimum energy.
        E_max (float): maximum energy.
        index (float): spectral index (default 2.7).

    Returns:
        float: sampled energy.
    """
    # Inverse transform sampling
    r = np.random.rand()
    exponent = 1.0 - index
    Emin_pow = E_min**exponent
    Emax_pow = E_max**exponent
    energies = (Emin_pow + r * (Emax_pow - Emin_pow)) ** (1.0 / exponent)
    
    return energies

# %%
def symmetry_loss(x, y, n_symmetry = 3, center = (0.0, 0.0)):
    """Compute a loss that penalizes deviation from n-fold rotational symmetry.

    The loss rotates the set of points and measures mean nearest-neighbour distance to the original set.

    Parameters:
        x, y (torch.Tensor): coordinates of detectors.
        n_symmetry (int): order of rotational symmetry to enforce.
        center (tuple): center point to rotate about.

    Returns:
        torch.Tensor: scalar symmetry loss (smaller is more symmetric).
    """
    #Penalizes deviation from n-fold rotational symmetry without relying on grouping.
    #Matches each rotated point to its nearest neighbor in the original set.
    x_centered = x - center[0]
    y_centered = y - center[1]
    coords = torch.stack([x_centered, y_centered], dim=1)  # (N, 2)

    sym_loss = 0.0
    for i in range(1, n_symmetry):
        theta = 2 * np.pi * i / n_symmetry
        R = torch.tensor([
            [np.cos(theta), -np.sin(theta)],
            [np.sin(theta),  np.cos(theta)]
        ], dtype=coords.dtype, device=coords.device)

        rotated = coords @ R.T  # (N, 2)

        # Compute pairwise distances between rotated and original coords
        dists = torch.cdist(rotated, coords, p=2)  # (N, N)

        # Find nearest neighbor for each rotated point
        min_dists, _ = dists.min(dim=1)

        sym_loss += min_dists.mean()

    return sym_loss / (n_symmetry - 1)

# %% [markdown]
# ## Utilities

# %%
def reconstructability(events):
    """Compute a differentiable reconstructability score per event.

    The score uses soft thresholds to estimate whether an event has enough detector hits
    to be reconstructable; returns a value in (0,1) per event.

    Parameters:
        events (torch.Tensor): per-event per-detector counts (shape: [Nevents, Nunits]).

    Returns:
        torch.Tensor: reconstructability scores per event.
    """
    layout_threshold = 5. #We accept the arrays detecting >= 5 particles
    tau_layout = 5.
    reconstruct_threshold = 3.
    tau_reconstruct = 5.

    soft_detect = torch.sigmoid(tau_layout * (events - layout_threshold))
    n = torch.sum(soft_detect, dim = 1)

    r = torch.sigmoid(tau_reconstruct * (n - reconstruct_threshold))

    return r

# %%
def U_PR(r):
    """Utility term for reconstructability: grows with the square-root of summed reconstructability.

    Parameters:
        r (torch.Tensor): reconstructability scores per event.

    Returns:
        torch.Tensor: scalar utility contribution.
    """
    u = torch.sqrt(torch.sum(r) + 1e-6) #1e-6 is for stability
    
    return u

# %%
def U_E(E_preds, E_trues, r):
    """Utility term for energy performance, weighted by reconstructability.

    Higher values indicate better agreement between predicted and true energies for reconstructable events.

    Parameters:
        E_preds (torch.Tensor): predicted energies (batch).
        E_trues (torch.Tensor): true energies (batch).
        r (torch.Tensor): reconstructability weights per event.

    Returns:
        torch.Tensor: scalar utility contribution.
    """
    u = torch.sum(r / ((E_preds - E_trues) ** 2 + .01))
    
    return u

# %%
def U_TH(Th_preds, Th_trues, r):
    """Utility term for angular performance (theta), weighted by reconstructability.

    Parameters:
        Th_preds (torch.Tensor): predicted theta values.
        Th_trues (torch.Tensor): true theta values.
        r (torch.Tensor): reconstructability weights per event.

    Returns:
        torch.Tensor: scalar utility contribution.
    """
    u = torch.sum(r / ((Th_preds - Th_trues) ** 2 + .00001))

    return u

# %% [markdown]
# # Neural Network
#
# In this section we are creating our neural network, we will train it with some simulated EAS. the idea is to feed the network with detector positions, with detected number of particles, and time of arrival. Then we neural network output will be energy of the shower, angles, and shower core (X, Y)
#
# We have to determine the number of hidden layers and number of neurons by hand, as there is no optimization regarding these parameters.
#
# We will keep learning rate small, ie. lr = 1e-5, otherwise NN tends to overfit
#
# It might be argued that for the first part there is no reason to keep positions of the detectors as inputs in our network, but that part will be useful when we need to train our NN again for new positions.

# %%
class Reconstruction(nn.Module):
    """Fully-connected neural network to reconstruct shower properties from flattened detector inputs.

    Inputs (per event) are flattened vectors of length `num_detectors * input_features` where for
    each detector the features are `[x, y, N, T]`.

    Outputs are a vector of length `output_dim` with `[X0, Y0, E_norm, Theta_norm, Phi_norm]`.
    """
    def __init__(self, input_features = 4, num_detectors = 90, hidden_lay1 = 256, hidden_lay2 = 128, 
                 hidden_lay3 = 32, output_dim = 5):
        super(Reconstruction, self).__init__()
        self.num_detectors = num_detectors
        self.input_features = input_features

        #We have to flatten the input, since we are using fully connected neural network
        self.L1 = nn.Linear(num_detectors * input_features, hidden_lay1)
        self.L2 = nn.Linear(hidden_lay1, hidden_lay2)
        self.L3 = nn.Linear(hidden_lay2, hidden_lay3)
        self.L4 = nn.Linear(hidden_lay3, output_dim)
        self.tanh = nn.Tanh()
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.1) #This way we drop a fraction of the neurons randomly at iteration,
        #So that our network won't rely on some specific network path

        #Output_dim = 5 means: we will have an output containing (X0, Y0, E0, Theta0, Phi0)

    def forward(self, x):
        """Forward pass: returns bounded outputs via `tanh` activation on top layer.

        Parameters:
            x (torch.Tensor): shape (batch_size, num_detectors * input_features)

        Returns:
            torch.Tensor: output tensor with normalized [X0, Y0, E_norm, Theta_norm, Phi_norm].
        """
        out = self.L1(x)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.L2(out)
        out = self.relu(out)
        out = self.L3(out)
        out = self.relu(out)
        out = self.L4(out)
        out = self.tanh(out)
        
        return out

# %%
#These functions are needed to normalize the labels and denormalize the outputs, otherwise the scales change too much that
#NN training will fail
def NormalizeLabels(E, theta, phi):
    """Normalize physical labels to the ranges expected by the network.

    Parameters:
        E, theta, phi (torch.Tensor): true energy, theta and phi.

    Returns:
        tuple: normalized (E_norm, theta_norm, phi_norm) in ranges roughly [-1,1] or equivalent.
    """
    E_norm = 2 * (E - .1) / (10 - .1) - 1
    theta_norm = 2 * theta / (theta_max) - 1
    phi_norm = phi / torch.pi
    
    return E_norm, theta_norm, phi_norm

def DenormalizeLabels(E_norm, theta_norm, phi_norm):
    """Inverse of `NormalizeLabels`: map normalized outputs back to physical units.

    Parameters:
        E_norm, theta_norm, phi_norm (torch.Tensor): normalized network outputs.

    Returns:
        tuple: denormalized (E, theta, phi).
    """
    E = 0.1 + (E_norm + 1) * (10 - 0.1) / 2
    theta = (theta_norm + 1) * theta_max / 2
    phi = phi_norm * torch.pi
    
    return E, theta, phi

# %%
#We use this class in the case of early stop
#If our network stops improving after some time there is no need to continue

class EarlyStopping:
    """Simple early stopping helper tracking validation loss improvements.

    Parameters:
        patience (int): number of epochs with no improvement before stopping.
        min_delta (float): minimum change to qualify as improvement.
    """
    def __init__(self, patience = 20, min_delta = 1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %% [markdown]
# # Global Variables

# %%
#Matrices we use in the functions
# PXmg_p, PXeg_p, PXmp_p, PXep_p = ReadShowers("./Fit_Photon_10_pars.txt", "./Fit_Proton_2_pars.txt")
A = torch.tensor([[1, 1, 1, 1],[1, 2, 4, 8], [1, 3, 9, 27], [1, 4, 16, 64]] , dtype = torch.float32)

#Constants
c0 = .29979 #Speed of light in [m / ns] units
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype = torch.float32)
log_10 = torch.tensor([np.log(10)], dtype = torch.float32)
sqrt12 = torch.tensor([np.sqrt(12)], dtype = torch.float32)

#Tank Values
IntegrationWindow = 128. #128 ns integration window, SWGO default
sigma_time = 10. #Time resolution assumed for the detectors
R_min = 2.
TankArea = 68.59 * np.pi #Area for 19 hexagonal macro unit
TankRadius = np.sqrt(68.59) #Radius of macro unit

#Background
Bgr_mu_per_m2 = 0.000001826 * IntegrationWindow
fluxB_m = torch.tensor([TankArea * Bgr_mu_per_m2])

Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

#Sizes
Nunits = 90
RelResCounts = .05

#Debug Parameters
largenumber = 1e13
epsilon = 1 / largenumber

#NN
Nevents = 100000
Nvalidation = 10000

#Layout
SWGOopt = False
x, y = Layouts()

x = torch.tensor(x, dtype = torch.float32)
y = torch.tensor(y, dtype = torch.float32)

# %% [markdown]
# # Main Routine
# We will be using here for debugging as well

# %% [markdown]
# ## Checks

# %%
# energy = torch.tensor([2.], requires_grad = True)
# theta = torch.tensor([np.pi / 6], requires_grad = True)
# R = torch.tensor(np.linspace(0, 1000, 500), requires_grad = True)
# fluxes = []

# for r in R:
#     fluxes.append(ShowerContent(energy, theta, r, "mg").item())

# plt.plot(R.detach().numpy(), fluxes, linewidth = 2)
# plt.grid()
# plt.yscale('log')
# plt.ylabel("Flux")
# plt.xlabel("R [m]")
# plt.xlim((0, 1000))
# plt.show()

# %%
# energy = torch.tensor([2.], requires_grad = True)
# theta = torch.tensor([np.pi / 6], requires_grad = True)
# R = torch.tensor(np.linspace(0, 1000, 500), requires_grad = True)
# fluxes = []

# for r in R:
#     fluxes.append(ShowerContent(energy, theta, r, "eg").item())

# plt.plot(R.detach().numpy(), fluxes, linewidth = 2)
# plt.grid()
# plt.yscale('log')
# plt.ylabel("Flux")
# plt.xlabel("R [m]")
# plt.xlim((0, 1000))
# plt.show()

# %%
# plt.figure(figsize = [6, 6])
# plt.scatter(x.detach(), y.detach(), color = "red")
# plt.grid()
# plt.xlabel("x [m]")
# plt.ylabel("y [m]")
# plt.title("Initial Position of the detectors")
# plt.xlim((-1100, 1100))
# plt.ylim((-1100, 1100))
# plt.show()

# %%
SWGOopt = False

# N, T, x0, y0, E, th, ph
N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = GenerateShowers(x, y)
# Out:
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.3510,  0.4872,  0.8733, -0.4262, -0.9046])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.44s

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
print("sin(theta):", sin_z)
print("cos(theta):", cos_z)
print("sin(phi):", sin_a)
print("cos(phi):", cos_a)
# Out:
# N: torch.Size([90, 1])
# T: torch.Size([90])
# X0: tensor(10.2675)
# Y0: tensor(14.7732)
# E: torch.Size([1])
# sin(theta): tensor([0.4872])
# cos(theta): tensor([0.8733])
# sin(phi): tensor([-0.4262])
# cos(phi): tensor([-0.9046])

# %%
# reconstruct theta and phi from sin and cos
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

# %%
print(f"Energy = {energy.item():.3f} PeV")
print(f"Angle = {th.item() * 180 / np.pi:.1f} degree")

idx = torch.where(N >= 1)[0]
norm = LogNorm(vmin = 2, vmax = torch.max(N).item())

plt.figure(figsize = [7, 6])
scatter = plt.scatter(x[idx], y[idx], c = N[idx], cmap = "viridis", norm = norm)
plt.colorbar(scatter, label='Number of detected particles')
plt.scatter(X0.item(), Y0.item(), c = "red", marker = "d")
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.xlim((-1100, 1100))
plt.ylim((-1100, 1100))
plt.show()
# Out:
# Energy = 9.351 PeV
# Angle = 29.2 degree

# %%
print(f"Angle = {th.item() * 180 / np.pi:.1f} degree")
print(f"Phi = {ph.item() * 180 / np.pi:.1f} degree")

norm = Normalize(vmin = torch.min(T), vmax = torch.max(T))

idx = torch.where(N >= 1)[0]
plt.figure(figsize = [7, 6])
scatter = plt.scatter(x[idx], y[idx], c = T[idx], cmap = "twilight", norm = norm)
plt.colorbar(scatter, label='Time of Arrival [ns]')
plt.scatter(X0.item(), Y0.item(), c = "green", marker = "d")
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.xlim((-1100, 1100))
plt.ylim((-1100, 1100))
plt.show()
# Out:
# Angle = 29.2 degree
# Phi = -154.8 degree

# %% [markdown]
# ## Training the Network
#
# We first need some simulations to train our neural network. In the global variables part, you will find a variable num_events, which is set to 10000. We will use this number to generate random events.

# %% [markdown]
# ### Test Data Generation
#
# Number of showers in the test set = 100k

# %%
Nevents=1000

# %%
# %%time

inputs = torch.zeros((Nevents, Nunits, 4))
labels = torch.zeros((Nevents, 5))

for i in range(Nevents):
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = GenerateShowers(x, y)
    # reconstruct theta and phi from sin and cos
    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)

    #Normalize the Labels:
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
    x0 = X0 / 5000 #[km]
    y0 = Y0 / 5000 #[km]

    input_vector = np.column_stack((x, y, N, T))

    inputs[i] = torch.tensor(input_vector, dtype = torch.float32)
    labels[i] = torch.tensor([x0, y0, E_norm, theta_norm, phi_norm], dtype = torch.float32)

    if (i + 1) % 10000 == 0:
        print(f"Shower generation is {int((i + 1) / 1000)}% done")
# Out:
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.5301,  0.7919,  0.6107, -0.5559,  0.8312])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.9847,  0.7875,  0.6164, -0.7549, -0.6558])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.06s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.6969,  0.3180,  0.9481,  0.9496, -0.3134])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.9812,  0.4974,  0.8675, -0.9000,  0.4359])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9950,  0.1934,  0.9811,  0.5288, -0.8487])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3580,  0.5491,  0.8357, -0.6048,  0.7964])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.5009,  0.4144,  0.9101,  0.1554, -0.9879])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.0658,  0.6700,  0.7424, -0.9257,  0.3783])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.5938e-01,  1.8606e-01,  9.8254e-01,  6.5747e-04, -1.0000e+00])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.4136,  0.4615,  0.8871,  0.9775, -0.2111])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.5580,  0.3621,  0.9321, -0.9904,  0.1385])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3635,  0.6716,  0.7409, -0.7711,  0.6368])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.3910,  0.2374,  0.9714,  0.2923, -0.9563])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.4658,  0.5029,  0.8643, -0.2404, -0.9707])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1779,  0.0798,  0.9968,  0.9958, -0.0914])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.9065,  0.6399,  0.7685, -0.9819, -0.1896])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3339,  0.5194,  0.8545, -0.7376,  0.6752])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.5555, 0.5677, 0.8233, 0.6467, 0.7627])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.1957,  0.7465,  0.6654,  0.6103, -0.7922])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9506,  0.7794,  0.6266, -0.3002,  0.9539])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.2429,  0.4594,  0.8882, -0.8826, -0.4702])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.4415,  0.4562,  0.8899, -0.1385,  0.9904])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.0090,  0.8923,  0.4515, -0.3360, -0.9419])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.5336,  0.6877,  0.7260, -0.4087,  0.9127])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.8375,  0.5004,  0.8658,  0.0266, -0.9996])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9630,  0.8675,  0.4974, -0.5559, -0.8312])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.5259,  0.2878,  0.9577, -0.9995, -0.0325])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.1523,  0.5284,  0.8490, -0.5265,  0.8502])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.9159,  0.2948,  0.9556,  0.5210, -0.8536])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.5863,  0.9022,  0.4313, -0.2702,  0.9628])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.4042,  0.8733,  0.4872, -0.9046, -0.4263])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.85s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.6983,  0.5442,  0.8390, -0.5142, -0.8576])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.4812, 0.5394, 0.8421, 0.8836, 0.4682])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.2239,  0.7020,  0.7122,  0.9235, -0.3835])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.0226,  0.0778,  0.9970, -0.1052, -0.9945])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.9127, 0.5162, 0.8565, 0.3605, 0.9328])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.8639,  0.1718,  0.9851,  0.3031, -0.9530])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.5887,  0.1858,  0.9826, -0.4066,  0.9136])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.1514,  0.4044,  0.9146, -0.6389, -0.7693])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.7643,  0.9038,  0.4280,  0.9840, -0.1781])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.6657, 0.8102, 0.5862, 0.6763, 0.7366])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.0785, 0.1384, 0.9904, 0.9689, 0.2476])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.9603,  0.5202,  0.8540, -0.8289, -0.5594])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.2901,  0.7191,  0.6949, -0.8060,  0.5919])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.5233,  0.5452,  0.8383, -0.2577,  0.9662])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.0893, 0.8927, 0.4506, 0.1412, 0.9900])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.9077,  0.4379,  0.8990, -0.1214,  0.9926])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.0565,  0.8610,  0.5087, -0.9868, -0.1617])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.3683,  0.3040,  0.9527,  0.5373, -0.8434])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.4275,  0.2521,  0.9677, -0.8712, -0.4909])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.3692, 0.6303, 0.7763, 0.1713, 0.9852])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.4261,  0.0430,  0.9991,  0.7273, -0.6863])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.1648,  0.8955,  0.4451,  0.3894, -0.9211])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.6807,  0.0601,  0.9982, -0.9998, -0.0212])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.0287,  0.2387,  0.9711, -0.8089,  0.5879])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.4324,  0.3939,  0.9192, -0.4290,  0.9033])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.3671,  0.8998,  0.4363,  0.8952, -0.4457])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.8127,  0.6573,  0.7536, -0.9200, -0.3919])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.8324, 0.2934, 0.9560, 0.6615, 0.7500])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9570,  0.2146,  0.9767, -0.4923,  0.8705])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.1215,  0.4460,  0.8950, -0.5375,  0.8433])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.0701,  0.8311,  0.5561, -0.9520, -0.3062])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.3096,  0.5814,  0.8136, -0.0605,  0.9982])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.5225, 0.7014, 0.7127, 0.3332, 0.9428])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.3566, 0.5090, 0.8608, 0.1625, 0.9867])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.8536,  0.2274,  0.9738, -0.9921, -0.1253])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.5538, 0.2759, 0.9612, 0.0761, 0.9971])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.9559, 0.5607, 0.8280, 0.1733, 0.9849])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.5616, 0.6949, 0.7191, 0.8603, 0.5098])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.7953, 0.0479, 0.9989, 0.4454, 0.8953])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.9907,  0.7432,  0.6691,  0.9005, -0.4348])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.5517,  0.2778,  0.9606, -0.8610, -0.5087])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.2556,  0.6374,  0.7706, -0.9900,  0.1411])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.1212,  0.1142,  0.9935, -0.9999,  0.0160])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2246,  0.7637,  0.6456, -0.8702,  0.4928])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.0456, 0.3079, 0.9514, 0.8369, 0.5473])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.2032,  0.7967,  0.6043, -0.5213,  0.8534])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.7807,  0.6517,  0.7585, -0.9946, -0.1034])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.3670,  0.0834,  0.9965, -0.7091, -0.7051])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.0181e+00,  3.7514e-01,  9.2697e-01, -1.0000e+00, -2.3104e-03])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.6625, 0.2574, 0.9663, 0.5903, 0.8072])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.8727,  0.7133,  0.7008, -0.6552,  0.7555])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.7632, 0.7191, 0.6949, 0.6894, 0.7244])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.3021,  0.6182,  0.7860,  0.4262, -0.9046])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.3038,  0.5067,  0.8621,  0.9801, -0.1985])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.1920,  0.8614,  0.5079, -0.2474,  0.9689])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1913,  0.2874,  0.9578, -0.8516,  0.5242])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.1160,  0.9003,  0.4352, -0.3101,  0.9507])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.9277,  0.1613,  0.9869, -0.8150,  0.5794])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.3713,  0.7077,  0.7065,  0.0683, -0.9977])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.1229,  0.9036,  0.4284, -0.2846, -0.9586])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9773,  0.7138,  0.7004, -0.9748, -0.2231])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.5855,  0.7668,  0.6419, -0.9985,  0.0543])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.5851,  0.6947,  0.7193,  0.4810, -0.8767])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.2742, 0.7272, 0.6865, 0.4495, 0.8933])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.8321, 0.4463, 0.8949, 0.3748, 0.9271])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.2993,  0.7153,  0.6988, -0.8276,  0.5613])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.3654,  0.6739,  0.7389,  0.9970, -0.0779])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.8289,  0.8299,  0.5580,  0.0211, -0.9998])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.9025, 0.1599, 0.9871, 0.9484, 0.3171])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.0819,  0.5759,  0.8176, -0.6317,  0.7752])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.5694,  0.7583,  0.6519, -0.9870,  0.1609])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.1857,  0.4622,  0.8868, -0.8756,  0.4830])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.1413,  0.3119,  0.9501,  0.9097, -0.4154])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.8049,  0.1400,  0.9901, -0.5206, -0.8538])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.9033, 0.6738, 0.7389, 0.9264, 0.3764])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.95s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.6034,  0.8946,  0.4469, -0.8511,  0.5250])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.6485, 0.8216, 0.5701, 0.1179, 0.9930])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.2042,  0.2198,  0.9755, -0.8899, -0.4561])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.3282, 0.3554, 0.9347, 0.8409, 0.5412])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.0827,  0.8618,  0.5072, -0.9878, -0.1556])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1311,  0.5004,  0.8658, -0.9140,  0.4058])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.01s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.3810,  0.3368,  0.9416,  0.2079, -0.9782])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.94s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.4183, 0.3746, 0.9272, 0.9982, 0.0593])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.4189, 0.7644, 0.6447, 0.6488, 0.7610])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.7730, 0.0203, 0.9998, 0.9807, 0.1955])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.5184,  0.2211,  0.9753, -0.1341,  0.9910])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.1034,  0.8414,  0.5403, -0.5467, -0.8374])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.8390,  0.4302,  0.9027, -0.0583, -0.9983])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.3995, 0.4935, 0.8697, 0.9732, 0.2300])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.9330,  0.0151,  0.9999, -0.7486,  0.6630])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.5668,  0.7486,  0.6630, -0.9874, -0.1581])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.2441,  0.7062,  0.7080, -0.1622, -0.9868])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.3775,  0.2811,  0.9597, -0.1511,  0.9885])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9822,  0.5921,  0.8059, -0.9191,  0.3941])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.8999,  0.2228,  0.9749,  0.8108, -0.5854])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.1145,  0.8714,  0.4906, -0.4950, -0.8689])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7203,  0.8444,  0.5357, -0.9711,  0.2388])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.9985,  0.9008,  0.4342, -0.8977, -0.4406])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.6261,  0.7958,  0.6056, -0.9311,  0.3649])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.1411,  0.6474,  0.7621, -0.7838, -0.6211])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.1729,  0.8425,  0.5387,  0.9829, -0.1841])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.5277, 0.6178, 0.7863, 0.9944, 0.1059])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.6389, 0.5263, 0.8503, 0.9963, 0.0858])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.5067,  0.8390,  0.5441, -0.6794, -0.7338])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.4542,  0.6060,  0.7955,  0.6302, -0.7765])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.4030,  0.5993,  0.8005,  0.8107, -0.5855])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.3717, 0.1609, 0.9870, 0.6757, 0.7372])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.1544, 0.3776, 0.9260, 0.3723, 0.9281])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7053,  0.6502,  0.7598, -0.2828,  0.9592])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.3393,  0.0570,  0.9984, -0.2610, -0.9653])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.2177,  0.2722,  0.9622, -0.2712,  0.9625])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.0946,  0.5893,  0.8079,  0.4525, -0.8918])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.9238,  0.2915,  0.9566,  0.8914, -0.4532])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.4781,  0.2462,  0.9692, -0.0644, -0.9979])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.0532,  0.8562,  0.5166, -0.6514,  0.7587])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.2864,  0.4874,  0.8732, -0.3352,  0.9422])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.1417,  0.6575,  0.7535, -0.8639,  0.5037])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3963,  0.3930,  0.9195,  0.1840, -0.9829])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.4190,  0.6280,  0.7782, -0.2367, -0.9716])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.3151,  0.1378,  0.9905, -0.9999, -0.0105])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.5701, 0.3850, 0.9229, 0.9088, 0.4172])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.4259,  0.1415,  0.9899, -0.9210,  0.3896])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ...
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.3853, 0.8966, 0.4429, 0.6427, 0.7662])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.2101, 0.4330, 0.9014, 0.4420, 0.8970])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.97s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.2265, 0.8111, 0.5850, 0.9777, 0.2102])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.00s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3482,  0.4228,  0.9062, -0.3748,  0.9271])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.85s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.2050, 0.2840, 0.9588, 0.6010, 0.7992])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.5195,  0.8179,  0.5753, -0.3940,  0.9191])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.4159,  0.8995,  0.4370, -0.9992, -0.0404])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.0113, 0.8726, 0.4884, 0.1137, 0.9935])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.1661,  0.2195,  0.9756, -0.2844,  0.9587])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.9493, 0.3011, 0.9536, 0.3376, 0.9413])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.4513, 0.5040, 0.8637, 0.9527, 0.3039])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.4759,  0.9010,  0.4338, -0.9962,  0.0873])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.7541, 0.4263, 0.9046, 0.1733, 0.9849])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.00s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.3207,  0.8094,  0.5873, -0.0563,  0.9984])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.99s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.1702,  0.7790,  0.6270, -0.9720,  0.2348])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.2734,  0.5557,  0.8314,  0.9747, -0.2237])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.6069,  0.0123,  0.9999, -0.0412, -0.9992])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.3611,  0.7942,  0.6077, -0.1431,  0.9897])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.2303,  0.2852,  0.9585,  0.7716, -0.6361])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.3836,  0.9037,  0.4282, -0.0590,  0.9983])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.8519, 0.8181, 0.5751, 0.3677, 0.9299])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.7933, 0.8371, 0.5470, 0.8926, 0.4509])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.58s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.7667, 0.4136, 0.9105, 0.9561, 0.2930])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.4544,  0.8005,  0.5994, -0.9798, -0.2002])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.8276, 0.5605, 0.8282, 0.4406, 0.8977])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.9546,  0.7122,  0.7020, -0.7753,  0.6316])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9481,  0.6964,  0.7177, -0.4135,  0.9105])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.59s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.5409, 0.7993, 0.6009, 0.4836, 0.8753])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.2045,  0.2819,  0.9595, -0.3686, -0.9296])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.98s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.7591, 0.2975, 0.9547, 0.4597, 0.8881])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.01s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.4868,  0.1203,  0.9927,  0.5880, -0.8089])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.5614,  0.5116,  0.8592, -0.8277,  0.5611])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.7956, 0.8977, 0.4407, 0.9615, 0.2747])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.1545, 0.3422, 0.9396, 0.7684, 0.6400])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.6968, 0.1755, 0.9845, 0.9500, 0.3123])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.3213, 0.8334, 0.5527, 0.9989, 0.0476])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.8879,  0.0618,  0.9981, -0.7096, -0.7046])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.00s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1135,  0.2019,  0.9794,  0.2166, -0.9763])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.02s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.1639,  0.8873,  0.4612, -0.9589, -0.2837])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.89s
# CPU times: user 28min 23s, sys: 1.12 s, total: 28min 24s
# Wall time: 28min 33s
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\ninputs = torch.zeros((Nevents, Nunits, 4))\nlabels = torch.zeros((Nevents, 5))\n\nfor i in range(Nevents):\n    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = GenerateShowers(x, y)\n    # reconstruct theta and phi from sin and cos\n    th = torch.atan2(sin_z, cos_z)\n    ph = torch.atan2(sin_a, cos_a)\n\n    #Normalize the Labels:\n    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)\n    x0 = X0 / 5000 #[km]\n    y0 = Y0 / 5000 #[km]\n\n    input_vector = np.column_stack((x, y, N, T))\n\n    inputs[i] = torch.tensor(input_vector, dtype = torch.float32)\n    labels[i] = torch.tensor([x0, y0, E_norm, theta_norm, phi_norm], dtype = torch.float32)\n\n    if (i + 1) % 10000 == 0:\n        print(f"Shower generation is {int((i + 1) / 1000)}% done")\n\ntorch.save(inputs, "./NN_Files/inputs.pt")\ntorch.save(labels, "./NN_Files/labels.pt")\n')
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1470, in ExecutionMagics.time(self, line, cell, local_ns)
#    1468 if interrupt_occured:
#    1469     if exit_on_interrupt and captured_exception:
# -> 1470         raise captured_exception
#    1471     return
#    1472 return out
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1434, in ExecutionMagics.time(self, line, cell, local_ns)
#    1432 st = clock2()
#    1433 try:
# -> 1434     exec(code, glob, local_ns)
#    1435     out = None
#    1436     # multi-line %%time case
#
# File <timed exec>:23
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/serialization.py:966, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     963     f = os.fspath(f)
#     965 if _use_new_zipfile_serialization:
# --> 966     with _open_zipfile_writer(f) as opened_zipfile:
#     967         _save(
#     968             obj,
#     969             opened_zipfile,
#    (...)    972             _disable_byteorder_record,
#     973         )
#     974         return
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/serialization.py:828, in _open_zipfile_writer(name_or_buffer)
#     826 else:
#     827     container = _open_zipfile_writer_buffer
# --> 828 return container(name_or_buffer)
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/serialization.py:792, in _open_zipfile_writer_file.__init__(self, name)
#     785     super().__init__(
#     786         torch._C.PyTorchFileWriter(
#     787             self.file_stream, get_crc32_options(), _get_storage_alignment()
#     788         )
#     789     )
#     790 else:
#     791     super().__init__(
# --> 792         torch._C.PyTorchFileWriter(
#     793             self.name, get_crc32_options(), _get_storage_alignment()
#     794         )
#     795     )
#
# RuntimeError: Parent directory ./NN_Files does not exist.

# %%
torch.save(inputs, "./NN_Files/inputs.pt")
torch.save(labels, "./NN_Files/labels.pt")

# %% [markdown]
# ### Validation Set Data Generation
#
# Number of events in the validation set = 10k, i.e 10% of the training set

# %%
Nvalidation = 100

# %%
# %%time

inputs_val = torch.zeros((Nvalidation, Nunits, 4))
labels_val = torch.zeros((Nvalidation, 5))

for i in range(Nvalidation):
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = GenerateShowers(x, y)
    # reconstruct theta and phi from sin and cos
    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    
    #Normalize the Labels:
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
    x0 = X0 / 5000 #[km]
    y0 = Y0 / 5000 #[km]

    input_vector = np.column_stack((x, y, N, T))

    inputs_val[i] = torch.tensor(input_vector, dtype = torch.float32)
    labels_val[i] = torch.tensor([x0, y0, E_norm, theta_norm, phi_norm], dtype = torch.float32)

    if (i + 1) % 5 == 0:
        print(f"Shower generation is {int((i + 1) / 50)}% done")
# Out:
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.5364,  0.4278,  0.9039, -0.5542,  0.8324])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.02s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.6490,  0.1542,  0.9880, -0.4679, -0.8838])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.02s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.0788, 0.3863, 0.9224, 0.9520, 0.3062])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9955,  0.5362,  0.8441, -0.8392, -0.5439])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.4241, 0.4521, 0.8920, 0.4238, 0.9057])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.01s
# Shower generation is 0% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.3194,  0.1350,  0.9908, -0.9807, -0.1953])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.7700,  0.8902,  0.4555, -0.9335, -0.3587])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.2280, 0.5137, 0.8580, 0.6435, 0.7654])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.5370, 0.7611, 0.6487, 0.9911, 0.1328])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.5576,  0.4179,  0.9085,  0.9818, -0.1899])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Shower generation is 0% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.3483,  0.7931,  0.6091, -0.6895, -0.7243])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.9095,  0.8457,  0.5336, -0.9900,  0.1408])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.7101,  0.6930,  0.7210, -0.9999,  0.0133])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.9993, 0.4425, 0.8968, 0.7340, 0.6792])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.7323, 0.6981, 0.7160, 0.2011, 0.9796])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Shower generation is 0% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.7083, 0.6923, 0.7216, 0.9774, 0.2113])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.6465,  0.2994,  0.9541, -0.5477,  0.8367])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.8288,  0.5674,  0.8235, -0.0589, -0.9983])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.1617,  0.6114,  0.7913, -0.6348, -0.7727])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.05s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.5862, 0.3800, 0.9250, 0.8894, 0.4571])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.94s
# Shower generation is 0% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.9827,  0.3027,  0.9531, -0.2201,  0.9755])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2054,  0.5817,  0.8134, -0.5493, -0.8356])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.7804, 0.7152, 0.6989, 0.2744, 0.9616])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.2857,  0.0667,  0.9978,  0.0364, -0.9993])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.4234,  0.3362,  0.9418, -0.0884,  0.9961])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Shower generation is 0% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.7158, 0.4584, 0.8887, 0.2446, 0.9696])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.2379, 0.7840, 0.6207, 0.4813, 0.8766])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.8976,  0.3638,  0.9315, -0.3278, -0.9447])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.4750, 0.7124, 0.7018, 0.9534, 0.3017])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.99s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.2263, 0.3311, 0.9436, 0.9975, 0.0702])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.02s
# Shower generation is 0% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.0518, 0.0931, 0.9957, 0.9195, 0.3932])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.00s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.6505,  0.8559,  0.5171,  0.0059, -1.0000])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.0717,  0.4113,  0.9115, -0.5153,  0.8570])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.6979,  0.5375,  0.8432, -0.7361, -0.6769])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.4265,  0.5050,  0.8631,  0.9387, -0.3447])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Shower generation is 0% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.9293, 0.4384, 0.8988, 0.7276, 0.6860])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7181,  0.7548,  0.6559, -0.6004, -0.7997])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.6105,  0.3764,  0.9265, -0.9768,  0.2144])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.5309,  0.0183,  0.9998, -0.5997, -0.8003])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.60s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.1682,  0.1132,  0.9936, -0.9985, -0.0544])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Shower generation is 0% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.6895, 0.8919, 0.4523, 0.1834, 0.9830])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.9881, 0.4076, 0.9132, 0.4174, 0.9087])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.0299, 0.0225, 0.9997, 0.9938, 0.1111])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.4388,  0.4570,  0.8895,  0.1566, -0.9877])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.8873,  0.5735,  0.8192,  0.7661, -0.6427])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.61s
# Shower generation is 0% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.4131,  0.4734,  0.8809, -0.6848,  0.7287])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.07s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.8639, 0.7513, 0.6600, 0.9584, 0.2854])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.05s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.2662,  0.2284,  0.9736,  0.7441, -0.6681])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.0628,  0.3522,  0.9359, -0.1526,  0.9883])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.2611,  0.6036,  0.7973, -0.8454,  0.5341])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.3391,  0.3792,  0.9253, -0.8291, -0.5591])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.5619, 0.8228, 0.5684, 0.7993, 0.6009])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.3088,  0.2361,  0.9717,  0.8824, -0.4705])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.9589, 0.0084, 1.0000, 0.9938, 0.1108])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.3241,  0.0602,  0.9982,  0.8616, -0.5076])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.6383,  0.2134,  0.9770, -0.6824, -0.7310])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.5996,  0.8576,  0.5143, -0.2806, -0.9598])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.8150,  0.4985,  0.8669,  0.8607, -0.5090])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.0495,  0.2061,  0.9785,  0.4560, -0.8900])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.7959,  0.8618,  0.5072, -0.2095,  0.9778])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.0184, 0.7311, 0.6823, 0.2977, 0.9547])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.8793,  0.9004,  0.4350,  0.7356, -0.6775])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.0251,  0.1402,  0.9901, -0.3054, -0.9522])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.5935,  0.4864,  0.8737, -0.4386,  0.8987])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.2099,  0.0750,  0.9972, -0.9317, -0.3633])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.1724,  0.5131,  0.8583, -0.7532, -0.6578])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.2556,  0.0766,  0.9971,  0.9623, -0.2720])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.2536,  0.1443,  0.9895, -0.7548, -0.6560])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.3521, 0.8311, 0.5561, 0.1807, 0.9835])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.8999,  0.2413,  0.9705, -0.2187,  0.9758])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.2442,  0.1444,  0.9895, -0.1004,  0.9949])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.0556,  0.0592,  0.9982, -0.5999,  0.8001])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.7953,  0.3845,  0.9231, -0.5921,  0.8058])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.5807, 0.7489, 0.6627, 0.6823, 0.7310])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.0792, 0.4021, 0.9156, 0.9753, 0.2210])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.4978,  0.8153,  0.5791,  0.0554, -0.9985])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.3001,  0.8541,  0.5200, -0.7805, -0.6252])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.3004,  0.7881,  0.6156, -0.8776, -0.4794])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.1568,  0.2865,  0.9581, -0.9574,  0.2889])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.1607, 0.7423, 0.6700, 0.0442, 0.9990])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.6604, 0.6092, 0.7930, 0.1046, 0.9945])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.5854,  0.9013,  0.4332, -0.2937, -0.9559])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.9412,  0.7415,  0.6709, -0.9258, -0.3781])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.02s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.6120,  0.8418,  0.5398,  0.9113, -0.4118])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.96s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.5225,  0.1159,  0.9933,  0.2243, -0.9745])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.4847, 0.1247, 0.9922, 0.1550, 0.9879])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.98s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.2498, 0.1015, 0.9948, 0.9679, 0.2513])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.91s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.0517,  0.1079,  0.9942, -0.1772, -0.9842])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.02s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.0115, 0.6319, 0.7750, 0.0745, 0.9972])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.05s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9905,  0.0902,  0.9959,  0.8721, -0.4894])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.7329, 0.8089, 0.5880, 0.9192, 0.3938])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.6624,  0.2864,  0.9581,  0.9420, -0.3355])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.01s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.8440,  0.2221,  0.9750, -0.9599,  0.2803])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.03s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.0040,  0.5200,  0.8542,  0.2007, -0.9797])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.81s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.7769,  0.0418,  0.9991, -0.7233,  0.6905])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.05s
# Shower generation is 1% done
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.8119,  0.9034,  0.4287, -0.2492,  0.9685])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.05s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.0933, 0.7458, 0.6661, 0.9987, 0.0503])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.77s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.9087,  0.2082,  0.9781, -1.0000,  0.0044])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.0824, 0.3108, 0.9505, 0.9915, 0.1299])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.8028,  0.4745,  0.8802, -0.7071,  0.7072])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Shower generation is 2% done
# CPU times: user 2min 54s, sys: 156 ms, total: 2min 54s
# Wall time: 2min 55s
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\ninputs_val = torch.zeros((Nvalidation, Nunits, 4))\nlabels_val = torch.zeros((Nvalidation, 5))\n\nfor i in range(Nvalidation):\n    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = GenerateShowers(x, y)\n    # reconstruct theta and phi from sin and cos\n    th = torch.atan2(sin_z, cos_z)\n    ph = torch.atan2(sin_a, cos_a)\n\n    #Normalize the Labels:\n    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)\n    x0 = X0 / 5000 #[km]\n    y0 = Y0 / 5000 #[km]\n\n    input_vector = np.column_stack((x, y, N, T))\n\n    inputs_val[i] = torch.tensor(input_vector, dtype = torch.float32)\n    labels_val[i] = torch.tensor([x0, y0, E_norm, theta_norm, phi_norm], dtype = torch.float32)\n\n    if (i + 1) % 5 == 0:\n        print(f"Shower generation is {int((i + 1) / 50)}% done")\n\ntorch.save(inputs_val, "./NN_files/inputs_val.pt")\ntorch.save(labels_val, "./NN_files/labels_val.pt")\n')
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1470, in ExecutionMagics.time(self, line, cell, local_ns)
#    1468 if interrupt_occured:
#    1469     if exit_on_interrupt and captured_exception:
# -> 1470         raise captured_exception
#    1471     return
#    1472 return out
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1434, in ExecutionMagics.time(self, line, cell, local_ns)
#    1432 st = clock2()
#    1433 try:
# -> 1434     exec(code, glob, local_ns)
#    1435     out = None
#    1436     # multi-line %%time case
#
# File <timed exec>:23
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/serialization.py:966, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     963     f = os.fspath(f)
#     965 if _use_new_zipfile_serialization:
# --> 966     with _open_zipfile_writer(f) as opened_zipfile:
#     967         _save(
#     968             obj,
#     969             opened_zipfile,
#    (...)    972             _disable_byteorder_record,
#     973         )
#     974         return
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/serialization.py:828, in _open_zipfile_writer(name_or_buffer)
#     826 else:
#     827     container = _open_zipfile_writer_buffer
# --> 828 return container(name_or_buffer)
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/serialization.py:792, in _open_zipfile_writer_file.__init__(self, name)
#     785     super().__init__(
#     786         torch._C.PyTorchFileWriter(
#     787             self.file_stream, get_crc32_options(), _get_storage_alignment()
#     788         )
#     789     )
#     790 else:
#     791     super().__init__(
# --> 792         torch._C.PyTorchFileWriter(
#     793             self.name, get_crc32_options(), _get_storage_alignment()
#     794         )
#     795     )
#
# RuntimeError: Parent directory ./NN_files does not exist.

# %%
torch.save(inputs_val, "./NN_Files/inputs_val.pt")
torch.save(labels_val, "./NN_Files/labels_val.pt")

# %% [markdown]
# ### Load the Sets

# %%
inputs = torch.load("./NN_Files/inputs.pt")
labels = torch.load("./NN_Files/labels.pt")

inputs_val = torch.load("./NN_Files/inputs_val.pt")
labels_val = torch.load("./NN_Files/labels_val.pt")

# %% [markdown]
# ### Model

# %%
#In this part we are defining our model, which is the Neural network for our reconstruction
#We will use Mean Square Error Loss
#Optimization model is SGD, to keep consistent with our next steps

model = Reconstruction()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 3e-5)

# %%
dataset = TensorDataset(inputs, labels)

dataloader = DataLoader(dataset, batch_size = 256, shuffle = True, drop_last = True, num_workers = 4)

# %%
# %%time

val_losses = []
losses = []

early_stopper = EarlyStopping()

for num_epoch in range(1000):

    epoch_loss = 0
    total_batch = 0
    
    for batch_inputs, batch_labels in dataloader:
        batch_size = batch_inputs.size(0)

        train_x = batch_inputs.view(batch_size, -1)
        
        train_y = batch_labels.view(batch_size, -1)
        
        #Train the network
        outputs = model(train_x)

        loss = criterion(outputs, train_y)
        epoch_loss += loss.item()
        total_batch += 1

        loss.backward()
        optimizer.step()

        optimizer.zero_grad()

    #See if our loss in our validation set improves:
    val_size = inputs_val.size(0)

    val_x = inputs_val.view(val_size, -1)
    val_y = labels_val.view(val_size, -1)

    model.eval()

    with torch.no_grad():

        val_output = model(val_x)
        val_loss = criterion(val_output, val_y)
    
    val_losses.append(val_loss.item())
    early_stopper(val_loss)

    if (num_epoch + 1) % 100 == 0:
        print(f"Training is {int((num_epoch + 1) / 10)}% done, with Loss = {val_loss:.2f}")

    losses.append(epoch_loss / total_batch)

    if early_stopper.early_stop:
        print(f"Early stop at epoch {num_epoch + 1}")
        print(f"Validation loss = {val_loss:.2f}")
        print(f"Training loss = {epoch_loss / total_batch:.2f}")
        break

plt.plot(np.arange(1, len(losses) + 1), losses, color = "blue", label = "Training Loss")
plt.plot(np.arange(1, len(val_losses) + 1), val_losses, color = "red", label = "Validation Loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid()
# Out:
# Early stop at epoch 77
# Validation loss = 1.01
# Training loss = 0.87
# CPU times: user 1.81 s, sys: 3.66 s, total: 5.46 s
# Wall time: 9.89 s

# %%
torch.save(model.state_dict(), "./NN_Files/model_weights.pth")

# %%
model.load_state_dict(torch.load('./NN_Files/model_weights.pth'))

E_r = []
E_p = []

X_r = []
X_p = []

Y_r = []
Y_p = []

Th_r = []
Th_p = []

Ph_r = []
Ph_p = []

for i in range(1000):
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = GenerateShowers(x, y)
    # reconstruct theta and phi from sin and cos
    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    
    #Normalize the Labels:
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
    x0 = X0 / 5000 #[km]
    y0 = Y0 / 5000 #[km]
    
    X = torch.tensor(np.column_stack((x, y, N, T)), dtype = torch.float32)
    X = X.view(1, -1)

    model.eval()

    with torch.no_grad():
        output = model(X)

    x_pred = output[0, 0]
    y_pred = output[0, 1]
    E_pred = output[0, 2]

    theta_pred = output[0, 3]
    phi_pred = output[0, 4]
    E_pred, theta_pred, phi_pred = DenormalizeLabels(E_pred, theta_pred, phi_pred)
    
    E_p.append(E_pred)
    E_r.append(energy.item())

    X_r.append(x0.item())
    X_p.append(x_pred * 5000)

    Y_r.append(y0.item())
    Y_p.append(y_pred * 5000)

    Th_r.append(th.item())
    Th_p.append(theta_pred)

    Ph_r.append(ph.item())
    Ph_p.append(phi_pred)

    if (i + 1) % 20 == 0:
        print(f"Predicted: {E_pred:.1f}, Real: {energy.item():.1f}")
# Out:
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.2398,  0.3599,  0.9330, -0.0029, -1.0000])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.8507,  0.8646,  0.5024, -0.7471, -0.6647])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.1420,  0.4076,  0.9132, -0.5694,  0.8221])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.77s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.5452, 0.6726, 0.7400, 0.9155, 0.4022])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.4203,  0.4115,  0.9114,  0.8558, -0.5173])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.6701, 0.1113, 0.9938, 0.9806, 0.1959])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.8557,  0.3044,  0.9525, -0.9700,  0.2431])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.3411,  0.0203,  0.9998,  0.7449, -0.6672])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.4474,  0.8023,  0.5970, -0.9504, -0.3111])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.4468,  0.0703,  0.9975, -0.8695, -0.4939])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.3308, 0.8122, 0.5833, 0.6760, 0.7369])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.9470,  0.4269,  0.9043,  0.4917, -0.8708])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.3384,  0.2505,  0.9681, -0.7298, -0.6837])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.0250,  0.1323,  0.9912, -0.9715, -0.2370])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.2275,  0.2334,  0.9724,  0.2358, -0.9718])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.1842, 0.7500, 0.6614, 0.7702, 0.6378])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.5392,  0.8947,  0.4467,  0.9479, -0.3187])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.8435,  0.7070,  0.7072, -0.5317,  0.8469])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.5538,  0.5173,  0.8558, -0.9995,  0.0307])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.3289, 0.3168, 0.9485, 0.5935, 0.8048])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Predicted: 0.1, Real: 2.3
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.3407,  0.4425,  0.8967, -0.7270,  0.6866])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.9178,  0.7973,  0.6035, -0.1785, -0.9839])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.2492,  0.1012,  0.9949, -0.7381,  0.6747])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.4640, 0.6254, 0.7803, 0.9970, 0.0776])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.4586,  0.2398,  0.9708, -0.8975, -0.4410])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.1141,  0.3807,  0.9247, -0.8260,  0.5636])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.07s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.3713,  0.2500,  0.9682, -0.9997, -0.0250])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.81s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.1408,  0.5594,  0.8289, -0.2060, -0.9786])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.9202, 0.8237, 0.5671, 0.9588, 0.2840])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.8512,  0.0432,  0.9991,  0.4935, -0.8697])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.5996,  0.3701,  0.9290,  0.7035, -0.7107])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.0736,  0.6027,  0.7979, -0.9935, -0.1140])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.5317,  0.9000,  0.4360,  0.0453, -0.9990])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.6382,  0.8799,  0.4751, -0.5505,  0.8348])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.3388, 0.6100, 0.7924, 0.6455, 0.7638])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.5962,  0.1862,  0.9825, -0.9181, -0.3964])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.7210, 0.8947, 0.4466, 0.9994, 0.0342])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.7557,  0.4777,  0.8785, -0.2572, -0.9664])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.9813, 0.5826, 0.8127, 0.9712, 0.2383])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.9512,  0.7793,  0.6266,  0.9747, -0.2234])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Predicted: 0.1, Real: 9.0
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.6257,  0.4156,  0.9095,  0.9644, -0.2646])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.6391,  0.8862,  0.4633, -0.3507,  0.9365])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.2416, 0.7581, 0.6522, 0.1062, 0.9943])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.2463,  0.5871,  0.8095, -0.2143,  0.9768])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.5179,  0.5862,  0.8101, -0.7935,  0.6086])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.3602,  0.7562,  0.6543,  0.1696, -0.9855])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.4713, 0.3503, 0.9366, 0.9437, 0.3309])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3638,  0.3082,  0.9513,  0.6311, -0.7757])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.6401,  0.4401,  0.8980,  0.7739, -0.6333])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.4417, 0.4846, 0.8747, 0.4593, 0.8883])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.1198, 0.7768, 0.6298, 1.0000, 0.0055])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.7685, 0.8943, 0.4474, 0.0470, 0.9989])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.8832,  0.1604,  0.9871,  0.9521, -0.3056])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.01s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.4598,  0.8406,  0.5416,  0.7900, -0.6131])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.5943,  0.0673,  0.9977, -0.6865,  0.7271])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.8881,  0.6822,  0.7311, -0.2650, -0.9642])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.06s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.4452,  0.8331,  0.5532, -0.7116,  0.7026])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.78s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.1471,  0.5659,  0.8245, -0.9131, -0.4078])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.0651,  0.4985,  0.8669,  0.9523, -0.3050])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.5702, 0.1715, 0.9852, 0.8616, 0.5076])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Predicted: 0.1, Real: 6.6
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.5005,  0.4465,  0.8948,  0.3829, -0.9238])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.3116,  0.3346,  0.9424, -0.9811, -0.1938])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3638,  0.3069,  0.9518,  0.0227, -0.9997])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.4047,  0.7597,  0.6503, -0.3300,  0.9440])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.3047, 0.5968, 0.8024, 0.0086, 1.0000])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7377,  0.5074,  0.8617,  0.6193, -0.7852])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.7897,  0.8848,  0.4659, -0.9147, -0.4042])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.4623,  0.2497,  0.9683, -0.7903, -0.6127])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.9876,  0.1284,  0.9917, -0.7141, -0.7000])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.6363,  0.0573,  0.9984, -0.9985, -0.0543])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.6284,  0.8554,  0.5179,  0.1087, -0.9941])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.4179,  0.5166,  0.8562,  0.4689, -0.8833])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.8853, 0.1918, 0.9814, 0.4206, 0.9072])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.0993,  0.6419,  0.7668, -0.9426,  0.3341])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.5309,  0.3906,  0.9206,  0.8767, -0.4810])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.1512,  0.1544,  0.9880, -0.8582, -0.5133])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.5748,  0.8543,  0.5198, -0.9647,  0.2633])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.8860, 0.2333, 0.9724, 0.9636, 0.2674])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.5033,  0.0067,  1.0000,  0.4036, -0.9149])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.4192,  0.2615,  0.9652, -0.4151, -0.9098])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.03s
# Predicted: 0.1, Real: 2.4
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.5098,  0.8317,  0.5552,  0.8250, -0.5651])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.3007,  0.1260,  0.9920, -0.4310,  0.9023])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.78s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2390,  0.2984,  0.9544, -0.0772, -0.9970])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.9694,  0.0346,  0.9994,  0.7696, -0.6386])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.5064,  0.6445,  0.7646, -0.5931, -0.8051])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.05s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.0587,  0.2530,  0.9675, -0.1398,  0.9902])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.4364,  0.2495,  0.9684, -0.9804, -0.1972])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.82s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.8764,  0.1807,  0.9835, -0.9948, -0.1014])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.7295,  0.0828,  0.9966, -0.9103, -0.4138])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1770,  0.8412,  0.5408, -0.4228, -0.9062])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.8655,  0.4905,  0.8714, -0.4275, -0.9040])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.4149,  0.5311,  0.8473,  0.9713, -0.2378])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.06s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.9638, 0.1624, 0.9867, 0.9444, 0.3288])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.07s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.1099,  0.4626,  0.8866, -0.3089,  0.9511])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.5332,  0.6678,  0.7443, -0.0131,  0.9999])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.7517,  0.8852,  0.4653, -0.7169, -0.6972])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.6627,  0.5178,  0.8555,  0.3004, -0.9538])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.8741, 0.7396, 0.6731, 0.3679, 0.9299])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.4212, 0.4628, 0.8864, 0.2959, 0.9552])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.9443,  0.3958,  0.9183, -0.0296,  0.9996])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Predicted: 0.1, Real: 8.9
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.7688,  0.0984,  0.9951, -0.3105,  0.9506])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.1924,  0.8245,  0.5659,  0.9925, -0.1222])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.7138,  0.5706,  0.8212, -0.8784,  0.4779])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.7717,  0.0391,  0.9992, -0.9949, -0.1010])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.8755,  0.8930,  0.4500, -0.7343, -0.6788])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.2185,  0.0089,  1.0000, -0.5414, -0.8408])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.5947,  0.5646,  0.8254,  0.5603, -0.8283])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.9915,  0.4265,  0.9045, -0.6450,  0.7642])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7368,  0.7639,  0.6453, -0.7984,  0.6021])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.1318, 0.2845, 0.9587, 0.1073, 0.9942])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.8847,  0.1600,  0.9871,  0.5375, -0.8433])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.66s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.8911,  0.4811,  0.8767, -0.8664, -0.4994])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.05s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.7726,  0.3439,  0.9390, -0.2416,  0.9704])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.8839,  0.4691,  0.8831,  0.9873, -0.1587])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.77s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.2438,  0.7867,  0.6174, -0.3925, -0.9197])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.1385, 0.6345, 0.7729, 0.6622, 0.7494])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.6807, 0.6849, 0.7286, 0.9807, 0.1957])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.3213,  0.8872,  0.4614,  0.9916, -0.1295])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.5897,  0.8797,  0.4756,  0.9995, -0.0307])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.4429,  0.3479,  0.9375, -0.9693, -0.2460])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Predicted: 0.1, Real: 8.4
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.0936, 0.8582, 0.5132, 0.9393, 0.3431])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.1510, 0.2782, 0.9605, 0.6014, 0.7989])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.7756,  0.3495,  0.9369, -0.6204, -0.7843])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.1752e+00, 2.3350e-03, 1.0000e+00, 9.3502e-01, 3.5460e-01])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.5076,  0.8995,  0.4368,  0.3743, -0.9273])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.9679, 0.8202, 0.5721, 0.9761, 0.2172])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.2915,  0.6359,  0.7718, -0.3768,  0.9263])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.4928,  0.3040,  0.9527, -0.5938,  0.8046])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.2221,  0.0815,  0.9967,  0.6562, -0.7546])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2405,  0.0410,  0.9992, -0.2045,  0.9789])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.1655,  0.2981,  0.9545, -0.8744, -0.4852])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.05s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.5441,  0.6950,  0.7190, -0.9978,  0.0660])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.3313, 0.6969, 0.7172, 0.6977, 0.7164])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.0680,  0.1024,  0.9947,  0.9293, -0.3693])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.65s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.1376, 0.1469, 0.9891, 0.2895, 0.9572])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.9459,  0.0264,  0.9997,  0.0391, -0.9992])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.6417,  0.7301,  0.6834, -0.8901,  0.4558])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.0039, 0.7795, 0.6263, 0.5028, 0.8644])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.8460, 0.6308, 0.7759, 0.6145, 0.7889])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.9546,  0.3530,  0.9356, -0.5172,  0.8558])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Predicted: 0.1, Real: 2.0
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.1792,  0.1531,  0.9882, -0.5438, -0.8392])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.4261,  0.6055,  0.7958,  0.9993, -0.0375])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.6634, 0.7005, 0.7137, 0.9869, 0.1611])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.7437,  0.8220,  0.5695,  0.0669, -0.9978])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.6635,  0.0094,  1.0000, -0.3840, -0.9233])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.9286,  0.2564,  0.9666, -0.1844,  0.9828])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.7964,  0.1864,  0.9825,  0.8612, -0.5083])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.5732,  0.8598,  0.5106,  0.2106, -0.9776])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.7604, 0.1865, 0.9825, 0.4426, 0.8967])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.3458,  0.6346,  0.7728,  0.7078, -0.7064])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.3033, 0.3138, 0.9495, 0.4365, 0.8997])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.1137, 0.5902, 0.8072, 0.8729, 0.4879])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# ...
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.5099,  0.2685,  0.9633, -0.9654,  0.2607])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.7890,  0.8594,  0.5113,  0.6163, -0.7875])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.6925,  0.1294,  0.9916,  0.3277, -0.9448])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.8891, 0.1205, 0.9927, 0.3447, 0.9387])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.6286, 0.6327, 0.7744, 0.9592, 0.2826])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.4336,  0.8927,  0.4507, -0.9277,  0.3733])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.6869,  0.7896,  0.6136,  0.1088, -0.9941])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.7900,  0.7553,  0.6554,  0.6241, -0.7814])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.0720,  0.4224,  0.9064, -0.7622,  0.6473])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.4645,  0.6213,  0.7836,  0.8096, -0.5870])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Predicted: 0.1, Real: 9.5
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.1885,  0.6510,  0.7590,  0.3700, -0.9290])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.06s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.7255,  0.1966,  0.9805, -0.9702, -0.2423])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.98s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.7632,  0.7841,  0.6207, -0.5449, -0.8385])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.00s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.9084,  0.7523,  0.6588, -0.9966,  0.0827])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.7544,  0.8749,  0.4843, -0.7118, -0.7024])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.5729,  0.1765,  0.9843, -0.5443, -0.8389])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7911,  0.8701,  0.4928, -0.6718,  0.7408])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.6703,  0.5783,  0.8158,  0.8869, -0.4620])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.6558, 0.8785, 0.4777, 0.7867, 0.6173])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.5239,  0.5691,  0.8222, -0.9996,  0.0285])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.4989,  0.1813,  0.9834, -0.1249,  0.9922])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.2256,  0.3676,  0.9300,  0.0487, -0.9988])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.5160,  0.7230,  0.6909,  0.6207, -0.7840])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9491,  0.8742,  0.4855,  0.8062, -0.5917])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.0471,  0.8812,  0.4727, -0.4956, -0.8685])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.7528,  0.5683,  0.8228, -0.6271,  0.7789])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.0061,  0.0408,  0.9992, -0.4157, -0.9095])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.0268,  0.7599,  0.6500, -0.2936, -0.9559])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.5239,  0.1414,  0.9899, -0.2817, -0.9595])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.1209, 0.6954, 0.7187, 0.9983, 0.0584])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Predicted: 0.1, Real: 2.1
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.9049,  0.7521,  0.6591, -0.9980,  0.0626])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.4823,  0.8506,  0.5258,  0.8443, -0.5359])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.2271,  0.8726,  0.4885, -0.9645, -0.2640])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.8958,  0.5591,  0.8291, -0.7419,  0.6705])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.3313,  0.4467,  0.8947, -0.5126,  0.8586])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.0524, 0.6793, 0.7338, 0.6279, 0.7783])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.3478,  0.1016,  0.9948, -0.8572,  0.5150])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.6674,  0.7582,  0.6520,  0.0463, -0.9989])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.67s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.7737,  0.3081,  0.9514, -0.5871,  0.8095])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.6457, 0.5491, 0.8357, 0.3919, 0.9200])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.2393,  0.5428,  0.8398,  0.9804, -0.1969])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.6262,  0.5929,  0.8053, -0.4828,  0.8757])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.7656,  0.0849,  0.9964, -0.0462, -0.9989])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.9243,  0.3876,  0.9218, -0.0692,  0.9976])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.8973,  0.6091,  0.7931, -0.4072,  0.9133])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.6449,  0.7071,  0.7072, -0.5199,  0.8542])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.9417,  0.1068,  0.9943,  0.4835, -0.8753])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.6150,  0.5424,  0.8401,  0.7749, -0.6321])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.64s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.2389,  0.8134,  0.5816, -0.9901,  0.1406])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3114,  0.8105,  0.5857,  0.7685, -0.6399])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.63s
# Predicted: 0.1, Real: 8.3

# %%
plt.scatter(E_r, E_p, alpha = .5, color = "r")
plt.plot(np.arange(.1, 10, .01), np.arange(.1, 10, .01), color = "black", linewidth = 4)
plt.xlabel("True E")
plt.ylabel("Predicted E")
plt.grid()

# %%
plt.scatter(X_r, X_p, alpha = .5, color = "r")
plt.plot(np.arange(-1000, 1000, 10), np.arange(-1000, 1000, 10), color = "black", linewidth = 4)
plt.xlabel("True X")
plt.ylabel("Predicted X")
plt.grid()

# %%
plt.scatter(Y_r, Y_p, alpha = .5, color = "r")
plt.plot(np.arange(-1000, 1000, 10), np.arange(-1000, 1000, 10), color = "black", linewidth = 4)
plt.xlabel("True Y")
plt.ylabel("Predicted Y")
plt.grid()

# %%
plt.scatter(Th_r, Th_p, alpha = .5, color = "r")
plt.plot(np.arange(0, np.pi * 65 / 180, .1), np.arange(0, np.pi * 65 / 180, .1), color = "black", linewidth = 4)
plt.xlabel("True Theta")
plt.ylabel("Predicted Theta")
plt.grid()

# %%
plt.scatter(Ph_r, Ph_p, alpha = .5, color = "r")
plt.plot(np.arange(- np.pi, np.pi, .1), np.arange(- np.pi, np.pi, .1), color = "black", linewidth = 4)
plt.xlabel("True Phi")
plt.ylabel("Predicted Phi")
plt.grid()

# %%
data = np.abs(np.array(Y_p) - np.array(Y_r))
idx_low = np.where(np.array(E_r) <= 3.)
idx_mid = np.where((np.array(E_r) <= 5.) & (np.array(E_r) > 3.))
idx_high = np.where(np.array(E_r) > 5.)

bin_high = np.logspace(np.log10(min(data[idx_high])), np.log10(max(data[idx_high])), 50)
bin_mid = np.logspace(np.log10(min(data[idx_mid])), np.log10(max(data[idx_mid])), 50)
bin_low = np.logspace(np.log10(min(data[idx_low])), np.log10(max(data[idx_low])), 50)

plt.hist(data[idx_high], bins = bin_high, alpha = .5, color = "blue", label = "High Energy Events")
plt.hist(data[idx_mid], bins = bin_mid, alpha = .5, color = "yellow", label = "Medium Energy Events")
plt.hist(data[idx_low], bins = bin_low, alpha = .5, color = "red", label = "Low Energy Events")
plt.xlabel("Core Position Y Loss")
plt.legend()
plt.xscale("log")
plt.ylabel("Counts")
plt.grid()
plt.show()

# %% [markdown]
# ## Optimization
#
# This is part where we start moving our arrays according to Utility Function.
#
# You can check the utilities that we use above and see that it is > 0
#
# So we will use -U as a "loss" function and minimize it, so that we can maximize our value

# %%
#First save the weights or load them so that we don't have to train the network every time we start the kernel
#Remove the commend operator "#" if you want to save

#torch.save(model.state_dict(), './NN_files/model_weights.pth')

model = Reconstruction()

path = Path("./NN_Files/checkpoint.pth")

if path.exists():
    checkpoint = torch.load('./NN_Files/checkpoint.pth')

    model.load_state_dict(checkpoint['model_state_dict'])
    print("Updated Weights are loaded")
    
else:
    model.load_state_dict(torch.load('./NN_Files/model_weights.pth'))
    print("Initial Weights are loaded")
# Out:
# Initial Weights are loaded

# %%
def barycentric_coords(P, A, B, C):
    """
    Compute barycentric coordinates for each point P with respect to triangle ABC.
    P: Tensor of shape (N, 2)
    A, B, C: Tensors of shape (2,)
    """
    v0 = C - A
    v1 = B - A
    v2 = P - A

    d00 = v0 @ v0
    d01 = v0 @ v1
    d11 = v1 @ v1
    d20 = torch.sum(v2 * v0, dim=1)
    d21 = torch.sum(v2 * v1, dim=1)

    denom = d00 * d11 - d01 * d01 + 1e-8
    u = (d11 * d20 - d01 * d21) / denom
    v = (d00 * d21 - d01 * d20) / denom
    return u, v

# %%
def project_to_triangle(x, y):
    """
    Projects each (x[i], y[i]) point inside the triangle defined by:
    A = (-3200, 2000), B = (1800, 2000), C = (1800, -3600)
    x, y: tensors of shape (N,)
    Returns: projected x and y, tensors of shape (N,)
    """
    A = torch.tensor([-3800.0, 1500.0], device=x.device)
    B = torch.tensor([1200.0, 1500.0], device=x.device)
    C = torch.tensor([1200.0, -4100.0], device=x.device)

    P = torch.stack([x, y], dim=1)  # (N, 2)

    # Compute barycentric coordinates
    u, v = barycentric_coords(P, A, B, C)

    # Determine which points are inside the triangle
    inside = (u >= 0) & (v >= 0) & (u + v <= 1)

    # Clip to triangle: u, v ∈ [0, 1], u + v ≤ 1
    u_clipped = torch.clamp(u, 0.0, 1.0)
    v_clipped = torch.clamp(v, 0.0, 1.0)
    uv_sum = u_clipped + v_clipped
    over = uv_sum > 1.0
    u_clipped[over] = u_clipped[over] / uv_sum[over]
    v_clipped[over] = v_clipped[over] / uv_sum[over]

    v0 = C - A
    v1 = B - A
    P_proj = A + u_clipped.unsqueeze(1) * v0 + v_clipped.unsqueeze(1) * v1

    # If already inside, keep P. Otherwise, use projection.
    final_P = torch.where(inside.unsqueeze(1), P, P_proj)

    return final_P[:, 0], final_P[:, 1]  # x_proj, y_proj

# %%
e = 0

for i in range(1000):
    p_layout = Path(f"./Python_Layouts/Layout_{i + 1}.txt")
    
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        
        x = torch.tensor(data[:, 0], dtype = torch.float32)
        y = torch.tensor(data[:, 1], dtype = torch.float32)
        e = i + 1

if e > 0:
    print(f"Updated Layout {e} is initialized")

else:
    print("First Layout is initialized")

class LearnableXY(torch.nn.Module):
    """Small module holding detector x,y positions as learnable parameters.

    The parameters can be optimized with standard PyTorch optimizers to change the layout.
    """
    def __init__(self, x_init, y_init):
        super().__init__()
        self.x = torch.nn.Parameter(x_init)
        self.y = torch.nn.Parameter(y_init)

    def forward(self):
        """Return current learnable coordinates as (x, y)."""
        return self.x, self.y

xy_module = LearnableXY(x, y)
# Out:
# First Layout is initialized

# %%
def push_apart(module, min_dist = 2 * TankRadius):
    """Enforce a minimum separation between detectors by small pairwise displacements.

    Parameters:
        module (LearnableXY): module exposing `x` and `y` parameters via forward().
        min_dist (float): desired minimum separation between detectors.
    """
    x, y = module()  # Correctly calls forward()
    coords = torch.stack([x, y], dim=1)  # shape (N, 2)

    with torch.no_grad():
        for i in range(coords.shape[0]):
            diffs = coords[i] - coords
            dists = torch.norm(diffs, dim=1)
            mask = (dists < min_dist) & (dists > 0)

            for j in torch.where(mask)[0]:
                direction = diffs[j] / dists[j]
                displacement = 0.5 * (min_dist - dists[j]) * direction
                coords[i] += displacement
                coords[j] -= displacement

        # Update learnable parameters in-place
        module.x.data.copy_(coords[:, 0])
        module.y.data.copy_(coords[:, 1])

# %%
# %%time

#Now we do the optimization step
SWGOopt = True
optimizer = torch.optim.SGD(xy_module.parameters(), lr = 5, momentum = .9)

# if path.exists():
#     optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
#     num_epoch = checkpoint.get("epoch") + 1
#     loss = checkpoint.get("loss")
    
#     print(f"Optimizer is initialized from the last epoch {num_epoch}")

# else:
num_epoch = 0
print("Optimizer is initialized")

max_grad = 10.

Nbatch = 10#50

if num_epoch < 20:
    Nfinetune = 25

elif num_epoch >= 20:
    Nfinetune = 50

U_vals = []
U_pr_vals = []
U_e_vals = []
U_th_vals = []

for epoch in range(num_epoch, num_epoch + 20):
    x1, y1 = xy_module()
    
    #Batch Generation:
    N_list = []
    T_list = []
    labels_batch = torch.zeros((Nbatch, 5))
    
    for i in range(Nbatch):
        N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = GenerateShowers(x1, y1)
        # reconstruct theta and phi from sin and cos
        th = torch.atan2(sin_z, cos_z)
        ph = torch.atan2(sin_a, cos_a)

        N_list.append(N)
        T_list.append(T)
        labels_batch[i] = torch.tensor([X0, Y0, energy, th, ph], dtype = torch.float32)
    
    x = x1.unsqueeze(0).repeat(Nbatch, 1)
    y = y1.unsqueeze(0).repeat(Nbatch, 1)

    events_n_batch = torch.stack(N_list).squeeze(-1)  # shape: (Nbatch, Nunits)
    events_t_batch = torch.stack(T_list).squeeze(-1)
    
    events_batch = torch.stack((x, y, events_n_batch, events_t_batch), dim = 2)
    
    model.eval()

    preds_batch = model(events_batch.view(Nbatch, -1))

    #Denormalize the predictions
    preds_x = preds_batch[:, 0] * 5000
    preds_y = preds_batch[:, 1] * 5000
    preds_e, preds_th, preds_phi = DenormalizeLabels(preds_batch[:, 2], preds_batch[:, 3], 
                                                                                preds_batch[:, 4])

    #Compute the reconstructability score for each event:
    r_score = reconstructability(events_batch[:, :, 2])
    density = Nbatch / ((labels_batch[:, 0].max() - labels_batch[:, 0].min()) * 
                        (labels_batch[:, 1].max() - labels_batch[:, 1].min()))

    #Compute Utility:
    U = 1e-2 * U_TH(preds_th, labels_batch[:, 3], r_score) + U_E(preds_e, labels_batch[:, 2], r_score) + U_PR(r_score) / torch.sqrt(density)

    #Save the utility values to plot
    U_vals.append(U.item())
    U_pr_vals.append((U_PR(r_score) / torch.sqrt(density)).item())
    U_e_vals.append(U_E(preds_e, labels_batch[:, 2], r_score).item())
    U_th_vals.append(1e-2 * U_TH(preds_th, labels_batch[:, 3], r_score).item())

    #sym_loss = symmetry_loss(x1, y1, n_symmetry = 3)
    print(f"Utility: {U:.2f}")

    #Use utility as - Loss, we have a penalty term to make configuration symmetric
    Loss = - U #+ lambda_sym * sym_loss

    Loss.backward()

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm = max_grad)

    optimizer.step()

    with torch.no_grad():
        push_apart(xy_module)

    #This part is done to keep the detectors inside the site
    """
    with torch.no_grad():
        x_proj, y_proj = project_to_triangle(x1.view(-1), y1.view(-1))
        x1.copy_(x_proj)
        y1.copy_(y_proj)
    """
    
    optimizer.zero_grad()

    #Now we need to generate new events that with the new layout so that we can fine tune our NN when it's necessary
    if (epoch + 1) % 5 == 0:
        print(f"Fine Tune at epoch {epoch + 1}")
        
        finetune_events = torch.zeros((Nfinetune, Nunits, 4))
        finetune_trues = torch.zeros((Nfinetune, 5))

        with torch.no_grad():
            x2, y2 = xy_module()
            x = x2.detach()
            y = y2.detach()

            #Generate events to fine tune the network
            for i in range(Nfinetune):
                N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = GenerateShowers(x, y)
                # reconstruct theta and phi from sin and cos
                theta = torch.atan2(sin_z, cos_z)
                phi = torch.atan2(sin_a, cos_a)

                X0 /= 5000
                Y0 /= 5000
                energy, theta, phi = NormalizeLabels(energy, theta, phi)

                finetune_events[i] = torch.tensor(np.column_stack((x, y, N, T)))
                finetune_trues[i] = torch.tensor([X0, Y0, energy, theta, phi], dtype = torch.float32)

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion = nn.MSELoss()
        optimizerNN = torch.optim.Adam(ReconstructionNN.parameters(), lr = 5e-5)

        dataset = TensorDataset(finetune_events, finetune_trues)
        dataloader = DataLoader(dataset, batch_size = 32, shuffle = True, drop_last = True, num_workers = 4)

        for j in range(5):
            for ft_batch, ft_trues in dataloader:
                batch_size = ft_batch.size(0)

                train_x = ft_batch.view(batch_size, -1)
        
                train_y = ft_trues.view(batch_size, 5)
        
                #Train the network
                outputs = ReconstructionNN(train_x)

                lossT = criterion(outputs, train_y)

                lossT.backward()
                optimizerNN.step()

                optimizerNN.zero_grad()

    #I will save the layouts and weights here so that I can stop whenever and continue later
    torch.save({"epoch": epoch, "loss": Loss, "model_state_dict": model.state_dict(), 
                "optimizer_state_dict": optimizer.state_dict()}, "./NN_Files/checkpoint.pth")
    
    np.savetxt(f"./Python_Layouts/Layout_{epoch + 1}.txt", np.column_stack((x1.detach().numpy(), y1.detach().numpy())))
# Out:
# Optimizer is initialized
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1048,  0.2063,  0.9785, -0.9331, -0.3596])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.12s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.0983,  0.3575,  0.9339, -0.3526,  0.9358])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.10s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.3320,  0.3987,  0.9171, -0.6439,  0.7651])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.88s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.9922,  0.3895,  0.9210, -0.2182,  0.9759])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.86s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.4050,  0.7343,  0.6788, -0.9989, -0.0460])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.82s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7029,  0.8232,  0.5677, -0.3192,  0.9477])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.2560,  0.4209,  0.9071,  0.5698, -0.8218])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.6571,  0.1247,  0.9922, -0.1487, -0.9889])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.5777,  0.0705,  0.9975, -0.8341, -0.5516])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.1676, 0.4130, 0.9107, 0.5759, 0.8175])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Utility: 13.08
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.8254, 0.8877, 0.4605, 0.1322, 0.9912])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.0062,  0.4369,  0.8995,  0.1061, -0.9944])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.6923,  0.3922,  0.9199,  0.3790, -0.9254])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.0932,  0.8598,  0.5106, -0.1478,  0.9890])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.8293,  0.6032,  0.7976,  0.0419, -0.9991])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.5812,  0.1784,  0.9840,  0.4573, -0.8893])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.7130,  0.1207,  0.9927, -0.9569, -0.2906])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.6177,  0.5274,  0.8496,  0.7196, -0.6944])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.5396,  0.0449,  0.9990, -0.8503,  0.5263])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.77s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.2266,  0.7874,  0.6164,  0.8613, -0.5081])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Utility: 20.62
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.3478,  0.3904,  0.9206, -0.7285, -0.6850])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.5928,  0.2342,  0.9722,  0.8107, -0.5855])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.84s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.0372,  0.4217,  0.9067, -0.8818, -0.4716])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.3683, 0.8934, 0.4492, 0.5437, 0.8393])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2811,  0.6361,  0.7716, -0.0703,  0.9975])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.90s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.6495, 0.7371, 0.6758, 0.5957, 0.8032])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.70s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.8481, 0.7854, 0.6190, 0.6808, 0.7325])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.8290,  0.4610,  0.8874,  0.1000, -0.9950])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1706,  0.0749,  0.9972, -0.9991, -0.0430])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.9203,  0.7914,  0.6113, -0.3449,  0.9386])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.70s
# Utility: 24.87
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.3239,  0.0687,  0.9976, -0.7542,  0.6567])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.0554,  0.7335,  0.6797, -0.8753, -0.4836])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.0764,  0.4675,  0.8840, -0.9973, -0.0733])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.7819,  0.3800,  0.9250, -0.0569, -0.9984])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.12s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.2833, 0.5372, 0.8434, 1.0000, 0.0076])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.94s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.7645,  0.1134,  0.9935, -0.2291,  0.9734])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.1866, 0.0280, 0.9996, 0.9114, 0.4116])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.85s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2543,  0.1449,  0.9894, -0.3927, -0.9197])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3708,  0.5728,  0.8197,  0.7618, -0.6478])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.4147,  0.8494,  0.5277, -0.8894,  0.4571])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Utility: 39.22
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.6874,  0.5754,  0.8179,  0.5660, -0.8244])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.0028,  0.2566,  0.9665,  0.7351, -0.6779])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.8220, 0.1439, 0.9896, 0.9418, 0.3361])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.9004,  0.7385,  0.6743, -0.6635,  0.7482])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.3298,  0.4324,  0.9017, -0.8787, -0.4773])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.5348,  0.7766,  0.6300, -0.9175, -0.3977])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.2226,  0.8857,  0.4643, -0.9977, -0.0680])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.82s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.2419,  0.5060,  0.8625, -0.9785, -0.2062])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.14s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.9576,  0.6586,  0.7525, -0.7316, -0.6817])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.89s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.5921,  0.6773,  0.7357, -0.3238,  0.9461])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Utility: 44.53
# Fine Tune at epoch 5
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.1377,  0.6324,  0.7746,  0.9150, -0.4035])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.70s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.9981,  0.8858,  0.4641, -0.6295,  0.7770])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.03s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.2442,  0.8391,  0.5440,  0.0308, -0.9995])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.16s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.3288,  0.7455,  0.6665, -0.8651,  0.5017])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.2353, 0.6959, 0.7182, 0.0180, 0.9998])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.4005,  0.3954,  0.9185,  0.1861, -0.9825])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.7588, 0.5102, 0.8600, 0.9370, 0.3495])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.1178,  0.8725,  0.4887, -0.9841,  0.1776])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.3376,  0.5392,  0.8422, -0.0685, -0.9977])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.7501,  0.2518,  0.9678, -0.7876,  0.6162])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.9463, 0.0273, 0.9996, 0.1422, 0.9898])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.2271,  0.3462,  0.9382, -0.9448, -0.3276])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.5857,  0.6485,  0.7612, -0.8381, -0.5455])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.12s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.5887,  0.9001,  0.4358, -0.3989,  0.9170])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.0524,  0.0195,  0.9998,  0.2164, -0.9763])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.02s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.6965,  0.5154,  0.8570,  0.2210, -0.9753])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.6858,  0.6467,  0.7628, -0.1275,  0.9918])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.5345,  0.7282,  0.6854,  0.9603, -0.2790])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.6572,  0.3063,  0.9519, -0.2432,  0.9700])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.6713,  0.8332,  0.5530, -0.1301,  0.9915])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1367,  0.5797,  0.8148,  0.6650, -0.7469])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.4648,  0.1502,  0.9886,  0.1791, -0.9838])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.2271, 0.8608, 0.5089, 0.2238, 0.9746])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7105,  0.1871,  0.9823, -0.8211, -0.5708])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.2224,  0.6057,  0.7957,  0.9970, -0.0774])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.3362, 0.6148, 0.7887, 0.2192, 0.9757])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.17s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.1979,  0.6961,  0.7179, -0.9961, -0.0886])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.1639,  0.0981,  0.9952, -0.4570, -0.8895])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.99s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.3016,  0.8648,  0.5020, -0.5205,  0.8539])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.6598,  0.3740,  0.9274, -0.9855, -0.1700])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.7393, 0.5990, 0.8007, 0.7567, 0.6538])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.8666, 0.5189, 0.8548, 0.5820, 0.8132])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.98s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.0232,  0.7094,  0.7048, -0.8324, -0.5542])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.10s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.2029, 0.6254, 0.7803, 0.9986, 0.0524])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.15s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.4838,  0.1482,  0.9890, -0.9385, -0.3453])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.15s
# Utility: 20.92
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.8290,  0.2646,  0.9644, -0.9950, -0.0994])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.16s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.2072,  0.0258,  0.9997, -0.7917,  0.6110])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.4912, 0.7306, 0.6828, 0.8944, 0.4473])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.95s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.2541,  0.4097,  0.9122, -0.9461,  0.3239])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.75s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.2389,  0.3666,  0.9304, -0.9218,  0.3877])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.09s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.0172, 0.5502, 0.8350, 0.6331, 0.7741])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.4818,  0.4253,  0.9050, -0.5822, -0.8131])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.2984,  0.0970,  0.9953, -0.8855, -0.4646])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.10s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.5755, 0.4672, 0.8842, 0.4708, 0.8823])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.8913,  0.5175,  0.8557, -0.4248, -0.9053])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.04s
# Utility: 29.16
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.0946,  0.4016,  0.9158, -0.0052,  1.0000])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.80s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.4001,  0.2903,  0.9569,  0.2130, -0.9770])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.4957,  0.3176,  0.9482,  0.5622, -0.8270])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.6830, 0.3308, 0.9437, 0.6854, 0.7282])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.96s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.7924,  0.0878,  0.9961, -0.2660, -0.9640])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.6178, 0.1515, 0.9885, 0.4296, 0.9030])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.10s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.9991,  0.5094,  0.8606, -0.4630,  0.8864])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.07s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.1589, 0.4840, 0.8751, 0.5108, 0.8597])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.8121,  0.7353,  0.6777,  0.5174, -0.8557])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.10s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.5548,  0.1220,  0.9925,  0.7057, -0.7085])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Utility: 16.98
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.0337, 0.0435, 0.9991, 0.1363, 0.9907])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.14s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.4778,  0.6307,  0.7760, -0.9952, -0.0975])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.76s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.4255,  0.4237,  0.9058,  0.9210, -0.3896])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.6735,  0.8009,  0.5988,  0.6128, -0.7902])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.5444,  0.0784,  0.9969, -0.9348,  0.3551])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.94s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.9830,  0.0199,  0.9998, -0.0563, -0.9984])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.10s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.5017,  0.4262,  0.9046, -0.9764, -0.2160])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.76s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.7670,  0.0859,  0.9963, -0.0380,  0.9993])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.5238,  0.6565,  0.7543, -0.7841,  0.6206])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.93s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.5488,  0.7612,  0.6485, -0.9710, -0.2391])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.14s
# Utility: 36.06
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.6043,  0.6321,  0.7749,  0.9702, -0.2422])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.15s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.5409,  0.5315,  0.8471, -0.6578, -0.7532])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.15s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.5876,  0.7632,  0.6462, -0.9340,  0.3572])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.00s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.3101, 0.7420, 0.6704, 0.9739, 0.2270])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.7234,  0.6450,  0.7642,  0.9763, -0.2162])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.5378, 0.7832, 0.6218, 0.1737, 0.9848])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.0834,  0.6886,  0.7251,  0.1741, -0.9847])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.0460,  0.2354,  0.9719, -0.2478,  0.9688])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.7971, 0.4263, 0.9046, 0.9695, 0.2451])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.3623,  0.2588,  0.9659, -0.3723, -0.9281])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Utility: 28.13
# Fine Tune at epoch 10
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.4407,  0.6057,  0.7957, -0.6502, -0.7597])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.6207,  0.7920,  0.6105, -0.6846, -0.7289])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.3977,  0.0896,  0.9960, -0.5733,  0.8194])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.7145,  0.6616,  0.7498, -0.2800, -0.9600])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.1440, 0.3157, 0.9489, 0.5398, 0.8418])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.2443,  0.6699,  0.7425,  0.8062, -0.5917])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2300,  0.8358,  0.5491, -0.7825, -0.6227])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.6982, 0.5847, 0.8113, 0.9803, 0.1974])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.72s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.3824,  0.4075,  0.9132,  0.8573, -0.5149])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.3368,  0.3855,  0.9227, -0.9256, -0.3785])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.7990,  0.1445,  0.9895,  0.9882, -0.1533])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.5365,  0.6355,  0.7721, -0.3914, -0.9202])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.2482, 0.4789, 0.8779, 0.9283, 0.3718])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# Condition (cpu): tensor([6.0249, 0.3855, 0.9227, 0.0860, 0.9963])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.76s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.8082, 0.8617, 0.5073, 0.7891, 0.6143])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.8850,  0.5688,  0.8225, -0.9999,  0.0164])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.9396,  0.7047,  0.7095, -0.9185, -0.3954])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.1692,  0.2231,  0.9748, -0.9990, -0.0436])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.7412, 0.7807, 0.6249, 0.7682, 0.6402])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.3967,  0.2671,  0.9637,  0.5110, -0.8596])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.94s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7458,  0.3021,  0.9533, -0.8933,  0.4494])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.10s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.5923,  0.5872,  0.8095,  0.8381, -0.5454])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.10s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.8166,  0.4317,  0.9020,  0.5408, -0.8412])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.89s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2368,  0.4172,  0.9088,  0.8746, -0.4849])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.62s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.5448, 0.9006, 0.4346, 0.3560, 0.9345])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.70s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.2936,  0.6104,  0.7921,  0.9924, -0.1227])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.15s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.1313,  0.8369,  0.5473,  0.6448, -0.7643])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# ...
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.7426,  0.0612,  0.9981, -0.9521, -0.3058])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.01s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.9332,  0.4299,  0.9029, -0.0393,  0.9992])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1516,  0.0124,  0.9999, -0.5804,  0.8144])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.14s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.5976,  0.1766,  0.9843, -0.5462,  0.8377])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# Condition (cpu): tensor([2.3785, 0.3883, 0.9215, 0.1217, 0.9926])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.14s
# Utility: 76.63
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.3765,  0.8378,  0.5460, -0.9798,  0.2002])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.14s
# Starting generation for condition 1/1
# Condition (cpu): tensor([5.0366, 0.1861, 0.9825, 0.4896, 0.8720])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.0942, 0.4793, 0.8777, 0.8857, 0.4642])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.4897, 0.6131, 0.7900, 0.1592, 0.9872])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.92s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.1629,  0.5374,  0.8433, -0.0803, -0.9968])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.8554, 0.6289, 0.7775, 0.1066, 0.9943])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([7.4481, 0.8677, 0.4971, 0.5861, 0.8102])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 4.8465,  0.8527,  0.5224, -0.9847,  0.1743])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.3076,  0.8563,  0.5164, -0.2956, -0.9553])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.1338,  0.1536,  0.9881, -0.4148,  0.9099])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Utility: 13.95
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.3441,  0.8505,  0.5259, -0.3183, -0.9480])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.70s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.2144,  0.7067,  0.7075, -0.9787, -0.2051])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.68s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.6569,  0.8996,  0.4367, -0.0348, -0.9994])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 3.4377,  0.5853,  0.8108, -0.3745, -0.9272])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.15s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.8888,  0.4731,  0.8810, -0.9757,  0.2190])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.15s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.0970,  0.1808,  0.9835, -0.6699,  0.7424])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.13s
# Starting generation for condition 1/1
# Condition (cpu): tensor([3.9733, 0.6913, 0.7226, 0.8410, 0.5411])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.97s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.2209,  0.2121,  0.9773,  0.5215, -0.8532])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.71s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.5596,  0.0965,  0.9953, -0.9994, -0.0339])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.89s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 5.7540,  0.5090,  0.8608, -0.9748, -0.2231])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.14s
# Utility: 48.88
# Fine Tune at epoch 20
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.3037,  0.7837,  0.6211, -0.2616, -0.9652])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.16s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.8311,  0.6646,  0.7472,  0.6653, -0.7466])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.17s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.6330,  0.5044,  0.8635,  0.8105, -0.5858])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([0.2156, 0.8857, 0.4643, 0.9956, 0.0941])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.90s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2711,  0.5354,  0.8446, -0.4028, -0.9153])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.70s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.9224, 0.0965, 0.9953, 0.9986, 0.0525])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 0.8997,  0.7780,  0.6283, -0.8948,  0.4465])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.79s
# Starting generation for condition 1/1
# Condition (cpu): tensor([4.5832, 0.4276, 0.9040, 0.7531, 0.6579])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.17s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 9.5450,  0.8974,  0.4413, -0.9999,  0.0108])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.15s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.0788,  0.5946,  0.8040, -0.7207,  0.6932])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.90s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 8.1811,  0.3186,  0.9479, -0.7322,  0.6811])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([1.7414, 0.2437, 0.9699, 0.6418, 0.7669])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.6780,  0.4978,  0.8673, -0.1419,  0.9899])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.4948,  0.2468,  0.9691,  0.0462, -0.9989])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.9788, 0.2005, 0.9797, 0.8816, 0.4720])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 6.9790,  0.2986,  0.9544, -0.2502, -0.9682])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.2825,  0.1337,  0.9910, -0.7535,  0.6575])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.73s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.7077,  0.4639,  0.8859,  0.4969, -0.8678])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([9.6821, 0.4465, 0.8948, 0.6512, 0.7589])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.74s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 2.3521,  0.2235,  0.9747, -0.6923, -0.7216])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.96s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.0315,  0.8650,  0.5018, -0.5176, -0.8556])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.08s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 1.7964,  0.3687,  0.9296,  0.9994, -0.0354])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 2.11s
# Starting generation for condition 1/1
# Condition (cpu): tensor([8.2037, 0.3669, 0.9303, 0.9936, 0.1132])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.94s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.7117,  0.8789,  0.4770, -0.8931,  0.4499])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.69s
# Starting generation for condition 1/1
# Condition (cpu): tensor([ 7.3364,  0.6935,  0.7205,  0.7065, -0.7078])
# Condition 1/1: 1/1 samples done
# Concatenated generated images for condition 1: torch.Size([1, 3, 32, 32])
# Finished condition 1/1
# ✔ Done: generated 1 images across 1 conditions.
# Total generation time: 1.70s
# CPU times: user 9min 42s, sys: 5.72 s, total: 9min 48s
# Wall time: 10min 19s

# %%
a, b = Layouts()

plt.figure(figsize = [6, 6])
plt.scatter(x.detach(), y.detach(), color = "red", alpha = .8, label = "Final Layout")
plt.scatter(a, b, color = "blue", alpha = .3, label = "Initial Layout")
#plt.plot([-3800, 1200, 1200, -3800], [1500, 1500, -4100, 1500], "k--", label = "SWGO Site")

#Add Shower Simulation Area
#ax = plt.gca()
#rect = patches.Rectangle((-3000, -3000), 6000, 6000, linewidth=1.5, edgecolor='green', facecolor='green',
                         #alpha=0.1, label='Shower Simulation Area')
#ax.add_patch(rect)

plt.grid()
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.title("Position of the detectors")
plt.legend()
plt.xlim((-3000, 3000))
plt.ylim((-3000, 3000))
plt.show()

# %%
utility_path = Path("./Python_Layouts/Utilities.txt")

if utility_path.exists():
    data = np.loadtxt(utility_path)
    u_t = data
    #u_p = data[:, 1]
    #u_e = data[:, 2]
    #u_a = data[:, 3]

    u_t = np.append(u_t, np.array(U_vals).ravel())
    #u_p = np.append(u_p, np.array(U_pr_vals).ravel())
    #u_e = np.append(u_e, np.array(U_e_vals).ravel())
    #u_a = np.append(u_a, np.array(U_th_vals).ravel())

    #data = np.column_stack((u_t, u_p, u_e, u_a))

    np.savetxt(utility_path, u_t)
    
else:
    u_t = U_vals
    #u_p = U_pr_vals
    #u_e = U_e_vals
    #u_a = U_th_vals
    
    #data = np.column_stack((u_t, u_p, u_e, u_a))
    np.savetxt(utility_path, u_t)

# %%
mean_ut = [np.mean(u_t[i - 4: i]) for i in range(4, len(u_t))]

# %%
plt.plot(u_t, color = "black", linestyle = "none", marker = "o", linewidth = .5, label = "Total Utility")
plt.plot(np.arange(4, len(u_t)), mean_ut, linestyle = "-", linewidth = 2, label = "Mean Utility")
#plt.plot(u_p, color = "orange", linestyle = "-.", label = "Reconstructability Utility")
#plt.plot(u_e, color = "green", linestyle = "-.", label = "Energy Utility")
#plt.plot(u_a, color = "purple", linestyle = "-.", label = "Angle Utility")
plt.legend()
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("Utility Score")
plt.ylim((0, np.max(u_t) + 1000))
plt.title("Utility Values per Optimization Step")
plt.show()
