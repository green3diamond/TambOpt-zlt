# %%
import pandas as pd

pd.set_option('display.max_columns', 50)
df =pd.read_csv('tambo/first_100k_rows.csv')

# %%
# df.info()
df.describe()
# Out:
#          shower            pdg  kinetic_energy              x              y  \
# count  100000.0  100000.000000   100000.000000  100000.000000  100000.000000
# mean        0.0      42.051510       25.126226      -0.860957       0.937164
# std         0.0     361.059427      809.127950     150.232673     137.847621
# min         0.0   -3122.000000        0.999905   -4965.283691   -3133.369873
# 25%         0.0      11.000000        1.525365      -4.932963      -5.104439
# 50%         0.0      22.000000        2.692450      -0.024051       0.006784
# 75%         0.0      22.000000        6.783036       4.168696       4.184311
# max         0.0    2212.000000   143295.750000    4191.930176    4062.612305
#
#                   nx             ny             nz           time    weight  \
# count  100000.000000  100000.000000  100000.000000  100000.000000  100000.0
# mean       -0.000139       0.000397      -0.997692       0.000015       1.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

input_names = ["X_transformed", "Y_transformed", "kinetic_energy", "time"]

sns.pairplot(df[input_names])

# %%
sns.pairplot(df[["X_transformed", "Y_transformed", "x", "y", "nx", "ny"]])
