# %%
import pyarrow.parquet as pq
import pyarrow as pa

# Open the parquet file
pf = pq.ParquetFile('processed_events/normalized_features_all.parquet')

# Read first 5 rows using iter_batches
first_batch = next(pf.iter_batches(batch_size=5))

# Convert to pandas DataFrame
df = pa.Table.from_batches([first_batch]).to_pandas()

df
# Out:
#    kinetic_energy  primary_kinetic_energy  X_transformed  Y_transformed  \
# 0       -0.205800               -1.490094       0.601975      -0.010381
# 1       -0.351933               -1.490094       0.497330      -0.436993
# 2        0.937462               -1.490094      -0.177233       0.073647
# 3       -0.823414               -1.490094       1.294355       0.044384
# 4        0.047583               -1.490094      -0.394172       0.037591
#
#    Z_transformed  distance  time_transformed  sin_azimuth  cos_azimuth  \
# 0       0.077629  0.079031          0.554574     0.105454     0.994424
# 1      -0.122028 -0.120700          0.504512     0.105454     0.994424
# 2      -1.519858 -1.518812          0.295731     0.105454     0.994424
# 3       1.275315  1.277413          0.758670     0.105454     0.994424
# 4      -1.919142 -1.918272          0.207371     0.105454     0.994424
#
#    sin_zenith  cos_zenith    event_id   pdg  plane
# 0    0.046285    0.998928  33619162.0  13.0   18.0
# 1    0.046285    0.998928  33619162.0  13.0   17.0
# 2    0.046285    0.998928  33619162.0  11.0   10.0
# 3    0.046285    0.998928  33619162.0  22.0    0.0
# 4    0.046285    0.998928  33619162.0  22.0    8.0

# %%
from nn import ShowerDataset

pdg_classes = [11, 13, 22]
hit_file = "../ml/processed_events/normalized_features_z_3.parquet"
n_planes = 24

full_dataset = ShowerDataset(hit_file, pdg_classes, n_planes=n_planes, normalize_events=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 hit_file = "../ml/processed_events/normalized_features_z_3.parquet"
#       5 n_planes = 24
# ----> 7 full_dataset = ShowerDataset(hit_file, pdg_classes, n_planes=n_planes, normalize_events=True)
#
# File ~/code/tambo/TambOpt/ml/nn.py:85, in ShowerDataset.__init__(self, hit_file, pdg_classes, n_planes, normalize_events)
#      79     event_counts_pivot.append(pivot)
#      81 # reshape to get
#      82 # one column for each particle class and plane combination
#      83 # one row for each event
#      84 # one value is the count of hits
# ---> 85 self.event_data = pd.concat(event_counts_pivot, axis=1).fillna(0)
#      87 # Normalize event-level targets such that the total counts per event are 1
#      88 self.normalize_events = normalize_events
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1465, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1586, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1945, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2185, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2182             from_this_thread.append(frame_custom_thread_id)
#    2184     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2185         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2187 frames_list = None
#    2189 if keep_suspended:
#    2190     # This means that we should pause again after a set next statement.
#
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2254, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2251                 queue.put(internal_cmd)
#    2252                 wait_timeout = TIMEOUT_FAST
# -> 2254         notify_event.wait(wait_timeout)
#    2255         notify_event.clear()
#    2257 finally:
#
# File ~/anaconda3/envs/ml/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/anaconda3/envs/ml/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
X_event, y_pdg, y_event, eid = full_dataset[0]

# %%
# features
print(X_event.shape)
X_event
# Out:
# torch.Size([9637, 10])
# tensor([[-0.2167, -1.4910,  0.7241,  ...,  0.9944,  0.0463,  0.9989],
#         [-0.3636, -1.4910,  0.5984,  ...,  0.9944,  0.0463,  0.9989],
#         [ 0.9325, -1.4910, -0.2120,  ...,  0.9944,  0.0463,  0.9989],
#         ...,
#         [-0.4883, -1.4910,  1.4600,  ...,  0.9944,  0.0463,  0.9989],
#         [ 0.2629, -1.4910, -0.3449,  ...,  0.9944,  0.0463,  0.9989],
#         [-0.9302, -1.4910,  0.9090,  ...,  0.9944,  0.0463,  0.9989]])

# %%
# pdg labels
print(y_pdg.shape)
y_pdg
# Out:
# torch.Size([9637])
# tensor([1, 1, 0,  ..., 2, 2, 2])

# %%
# pdg labels
print(y_event.shape)
y_event
# Out:
# torch.Size([72])
# tensor([-0.4638,  0.0000,  0.0000, -0.6967, -0.8520, -0.4403, -0.4071,  0.0401,
#          0.7275,  0.8144,  0.3814,  0.7015,  1.0080,  0.7554,  1.4223,  0.6572,
#          0.5817,  0.6211,  0.3052, -0.1175, -0.0334, -0.4407, -0.4738, -0.8192,
#         -0.1374,  0.0000,  0.0000, -0.6126, -0.7564, -0.2625, -0.0102,  0.2183,
#          0.8354,  1.2027,  1.1399,  1.8008,  1.4033,  1.9956,  1.2488,  1.8098,
#          1.5405,  0.8575,  1.1532,  0.7627,  0.3966,  0.4776,  0.1276, -0.1104,
#         -0.6776,  0.0000,  0.0000, -0.7903, -0.9128, -0.2298, -0.3656,  0.1490,
#          0.2732,  0.3530,  0.4148,  0.6826,  0.7298,  0.8696,  0.8157,  0.4673,
#         -0.0743, -0.1007, -0.0502, -0.3481, -0.6152, -0.9015, -0.8071, -0.6008])

# %%
# event ID
eid
# Out:
# 33619162.0

# %%
from nn import ShowerNetMultiTask
from nn import ShowerDataset
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchviz import make_dot
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split

dummy_input = torch.randn(1, 784)  # Batch size of 1, 784 input features
hidden_dim=128
n_planes=24
pdg_classes = [11, 13, 22]
hit_file = "../ml/processed_events/normalized_features_z_3.parquet"
full_dataset = ShowerDataset(hit_file, pdg_classes, n_planes=n_planes, normalize_events=True)
event_ids = full_dataset.event_ids

test_eid = event_ids[0]
remaining_ids = event_ids[1:]
train_ids, val_ids = train_test_split(remaining_ids, test_size=0.1, random_state=42)

id_to_idx = {eid: i for i, eid in enumerate(event_ids)}
train_idx = [id_to_idx[eid] for eid in train_ids]
val_idx = [id_to_idx[eid] for eid in val_ids]
test_idx = [id_to_idx[test_eid]]

train_dataset = Subset(full_dataset, train_idx)
val_dataset = Subset(full_dataset, val_idx)
test_dataset = Subset(full_dataset, test_idx)

input_dim = len(full_dataset.feature_cols)
n_classes = len(pdg_classes)
n_event_outputs = len(pdg_classes)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
model = ShowerNetMultiTask(input_dim, hidden_dim, n_classes, n_event_outputs, n_planes=n_planes)

loader = DataLoader(test_dataset, batch_size=1, shuffle=False,
                        collate_fn=lambda x: list(zip(*x)))
    
for X_batch, y_pdg_batch, y_event_batch, eids in loader:
    output = model(X_batch)
    break
# Out:
# Using device: cpu

# %%
output = model(X_batch)  # type: tuple
print(type(output), [type(x) for x in output])
# Out:
# <class 'tuple'> [<class 'list'>, <class 'torch.Tensor'>]

# %%
dot = make_dot(output[1].mean(), params=dict(model.named_parameters()))  # Correct usage


# Save or display the generated graph
dot.format = 'png'
dot.render('simple_net')
# Out:
# 'simple_net.png'

# %%
output[1].shape
# Out:
# torch.Size([1, 24, 3])

# %%
output[0][0].shape
# Out:
# torch.Size([9637, 3])
